# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
#자연발생 클러스터링(민원 단계 컬럼 생성)
from jenkspy import JenksNaturalBreaks

parks_df = pd.read_csv("src/RF_parksdf_week.csv")
#parks_df = pd.read_csv("src/RF_parksdf_sat.csv")
#parks_df = pd.read_csv("src/RF_parksdf_holi.csv")

# 1) IQR 계산
Q1 = parks_df["complaints_r300"].quantile(0.25)
Q3 = parks_df["complaints_r300"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# 2) 이상치 제거
outliers = parks_df[
    (parks_df["complaints_r300"] < lower_bound) |
    (parks_df["complaints_r300"] > upper_bound)
].copy()

parks_df = parks_df.drop(outliers.index).copy()

# 3) 필터된 데이터로 Jenks 적용
i = 3
breaks = JenksNaturalBreaks(n_classes=i)
breaks.fit(parks_df["complaints_r300"])
print("경계값:", breaks.breaks_)

# 4) 레이블 부여
parks_df["complaint_level"] = pd.cut(
    parks_df["complaints_r300"],
    bins=breaks.breaks_,
    labels=range(i),
    include_lowest=True
)
parks_df["complaint_level"].value_counts()
# Out:
# 경계값: [0, 913, 2107, 4099]
# complaint_level
# 0    800
# 1    459
# 2    273
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# outliers: 이미 생성된 이상치 DataFrame

# 1) 이상치 개수·기술통계
print("▶ 이상치 개수:", len(outliers))
print("\n▶ 이상치 complaints_r300 기술통계:")
print(outliers["complaints_r300"].describe())

# 2) 상위/하위 몇 건 살펴보기
print("\n▶ 이상치 샘플(상위 5건):")
print(outliers.sort_values("complaints_r300", ascending=False).head(), "\n")
print("▶ 이상치 샘플(하위 5건):")
print(outliers.sort_values("complaints_r300", ascending=True).head())

# 3) 구역(zone)별 이상치 분포
if "zone" in outliers.columns:
    zone_counts = outliers["zone"].value_counts().sort_values(ascending=False)
    print("\n▶ 이상치 구역별 분포:")
    print(zone_counts)

# 4) 시작/종료 시간 분포
print("\n▶ 이상치 Weekday_start 분포:")
print(outliers["Weekday_start"].value_counts().sort_index())
print("\n▶ 이상치 Weekday_end 분포:")
print(outliers["Weekday_end"].value_counts().sort_index())

# 5) 낮/밤 영업시간 평균 비교
if {"day_open_hours","night_open_hours"}.issubset(outliers.columns):
    print("\n▶ 이상치 낮·밤 평균 영업시간:")
    print("  낮 평균:",  outliers["day_open_hours"].mean())
    print("  밤 평균:",  outliers["night_open_hours"].mean())

# 6) 시각화 예시: complaints_r300 히스토그램
plt.figure(figsize=(6,4))
plt.hist(outliers["complaints_r300"], bins=30)
plt.title("이상치 complaints_r300 분포")
plt.xlabel("complaints_r300")
plt.ylabel("Count")
plt.show()
# Out:
# ▶ 이상치 개수: 93
#
# ▶ 이상치 complaints_r300 기술통계:
# count       93.000000
# mean      6888.774194
# std       4118.954353
# min       4162.000000
# 25%       4644.000000
# 50%       5785.000000
# 75%       6924.000000
# max      24051.000000
# Name: complaints_r300, dtype: float64
#
# ▶ 이상치 샘플(상위 5건):
#               address parking_type  operation_type  total_parking_spaces  \
# 168   강서구 화곡동 1030-33           NW               1                  27.0
# 169   강서구 화곡동 1030-33           NW               1                  27.0
# 166   강서구 화곡동 1030-33           NW               1                  27.0
# 167   강서구 화곡동 1030-33           NW               1                  27.0
# 1190    양천구 목동 532-18           NW               1                  30.0
#
#       base_parking_fee  base_parking_time  additional_unit_fee  \
# 168               50.0                5.0                 50.0
# 169               50.0                5.0                 50.0
# 166               50.0                5.0                 50.0
# 167               50.0                5.0                 50.0
# 1190              50.0                5.0                 50.0
#
#       additional_unit_time  fee1H  cctv_r300  ...  complaints_r300  \
# 168                    5.0  600.0          3  ...            24051
# 169                    5.0  600.0          3  ...            24051
# 166                    5.0  600.0          3  ...            23905
# 167                    5.0  600.0          3  ...            23905
# 1190                   5.0  600.0          4  ...            14726
#
#       Weekday_paid Weekday_operatingHours         lon        lat  \
# 168              Y                     24  126.839735  37.543908
# 169              Y                     24  126.839717  37.543908
# 166              Y                     24  126.839735  37.543908
# 167              Y                     24  126.839717  37.543908
# 1190             Y                     24  126.871634  37.544354
#
#       zoning_encoded  start_sin  start_cos       end_sin  end_cos
# 168               10        0.0        1.0 -2.449294e-16      1.0
# 169               10        0.0        1.0 -2.449294e-16      1.0
# 166               10        0.0        1.0 -2.449294e-16      1.0
# 167               10        0.0        1.0 -2.449294e-16      1.0
# 1190              10        0.0        1.0 -2.449294e-16      1.0
#
# [5 rows x 21 columns]
#
# ▶ 이상치 샘플(하위 5건):
#              address parking_type  operation_type  total_parking_spaces  \
# 1528    중구 신당동 251-7           NW               1                1092.0
# 731   마포구 망원동 418-14           NS               1                   1.0
# 202    강서구 화곡동 797-7           NW               1                  17.0
# 201    강서구 화곡동 797-7           NW               1                  17.0
# 732   마포구 망원동 418-38           NS               1                   1.0
#
#       base_parking_fee  base_parking_time  additional_unit_fee  \
# 1528             360.0                5.0                360.0
# 731              150.0                5.0                150.0
# 202              250.0                5.0                250.0
# 201              250.0                5.0                250.0
# 732              150.0                5.0                150.0
#
#       additional_unit_time   fee1H  cctv_r300  ...  complaints_r300  \
# 1528                   5.0  4320.0         17  ...             4162
# 731                    5.0  1800.0          2  ...             4176
# 202                    5.0  3000.0          1  ...             4202
# 201                    5.0  3000.0          1  ...             4202
# 732                    5.0  1800.0          2  ...             4240
#
#       Weekday_paid Weekday_operatingHours         lon        lat  \
# 1528             Y                     24  127.012141  37.567102
# 731              Y                     10  126.899814  37.555709
# 202              Y                     10  126.860862  37.532286
# 201              Y                     10  126.860862  37.532286
# 732              Y                     10  126.900461  37.555302
#
#       zoning_encoded  start_sin  start_cos       end_sin  end_cos
# 1528               8        0.0   1.000000 -2.449294e-16      1.0
# 731               10        0.5  -0.866025 -8.660254e-01      0.5
# 202               10        0.5  -0.866025 -8.660254e-01      0.5
# 201               10        0.5  -0.866025 -8.660254e-01      0.5
# 732               10        0.5  -0.866025 -8.660254e-01      0.5
#
# [5 rows x 21 columns]
#
# ▶ 이상치 Weekday_start 분포:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hjyhe\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weekday_start'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 25
#      23 # 4) 시작/종료 시간 분포
#      24 print("\n▶ 이상치 Weekday_start 분포:")
# ---> 25 print(outliers["Weekday_start"].value_counts().sort_index())
#      26 print("\n▶ 이상치 Weekday_end 분포:")
#      27 print(outliers["Weekday_end"].value_counts().sort_index())
#
# File c:\Users\hjyhe\anaconda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\hjyhe\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Weekday_start'

# %%
print(parks_df.columns)
# Out:
# Index(['address', 'parking_type', 'operation_type', 'total_parking_spaces',
#        'base_parking_fee', 'base_parking_time', 'additional_unit_fee',
#        'additional_unit_time', 'fee1H', 'cctv_r300', 'bus_r300',
#        'complaints_r300', 'Weekday_paid', 'Weekday_operatingHours', 'lon',
#        'lat', 'zoning_encoded', 'start_sin', 'start_cos', 'end_sin', 'end_cos',
#        'complaint_level'],
#       dtype='object')

# %%
'''# KMeans 기반 클러스터링

from sklearn.cluster import KMeans
import numpy as np
import pandas as pd

parks_df = pd.read_csv("src/RF_parksdf_week.csv")
#parks_df = pd.read_csv("src/RF_parksdf_sat.csv")
#parks_df = pd.read_csv("src/RF_parksdf_holi.csv")
parks_df.columns

# 1) IQR 계산
Q1 = parks_df["complaints_r300"].quantile(0.25)
Q3 = parks_df["complaints_r300"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# 2) 이상치 제거
parks_df = parks_df[
    (parks_df["complaints_r300"] >= lower_bound) &
    (parks_df["complaints_r300"] <= upper_bound)
].copy()

k = 3

X = parks_df["complaints_r300"].values.reshape(-1, 1)

kmeans = KMeans(n_clusters=k, random_state=0)
clusters = kmeans.fit_predict(X)

centers = kmeans.cluster_centers_.flatten()
sorted_idx = np.argsort(centers)
label_map = {old: new for new, old in enumerate(sorted_idx)}
sorted_labels = np.vectorize(label_map.get)(clusters)

parks_df["complaint_level"] = sorted_labels

parks_df["complaint_level"].value_counts().sort_index()
'''
# Out:
# '# KMeans 기반 클러스터링\n\nfrom sklearn.cluster import KMeans\nimport numpy as np\nimport pandas as pd\n\nparks_df = pd.read_csv("src/RF_parksdf_week.csv")\n#parks_df = pd.read_csv("src/RF_parksdf_sat.csv")\n#parks_df = pd.read_csv("src/RF_parksdf_holi.csv")\nparks_df.columns\n\n# 1) IQR 계산\nQ1 = parks_df["complaints_r300"].quantile(0.25)\nQ3 = parks_df["complaints_r300"].quantile(0.75)\nIQR = Q3 - Q1\nlower_bound = Q1 - 1.5 * IQR\nupper_bound = Q3 + 1.5 * IQR\n\n# 2) 이상치 제거\nparks_df = parks_df[\n    (parks_df["complaints_r300"] >= lower_bound) &\n    (parks_df["complaints_r300"] <= upper_bound)\n].copy()\n\nk = 3\n\nX = parks_df["complaints_r300"].values.reshape(-1, 1)\n\nkmeans = KMeans(n_clusters=k, random_state=0)\nclusters = kmeans.fit_predict(X)\n\ncenters = kmeans.cluster_centers_.flatten()\nsorted_idx = np.argsort(centers)\nlabel_map = {old: new for new, old in enumerate(sorted_idx)}\nsorted_labels = np.vectorize(label_map.get)(clusters)\n\nparks_df["complaint_level"] = sorted_labels\n\nparks_df["complaint_level"].value_counts().sort_index()\n'

# %%
#범주형 변수의 label을 [0,1]로 변환
from sklearn.preprocessing import LabelEncoder

le_dict = {}

for col in ["parking_type", "operation_type", "Weekday_paid", "Saturday_paid", "Holiday_paid"]:
    if col in parks_df.columns:  # ✅ 존재하는 경우에만 처리
        le = LabelEncoder()
        parks_df[col] = le.fit_transform(parks_df[col])
        le_dict[col] = le

# 예시: parking_type의 범주와 정수 매핑 확인
for col in le_dict:
    print(f"{col}: {list(le_dict[col].classes_)}")

# [0, 1, 2, ...] 순서로 classes_에 저장됨
#['NS', 'NW'] -> [0,1]
#[1, 3] -> [0,1]
#['N', 'Y'] -> [0,1]
#['N', 'Y'] -> [0,1]
#['N', 'Y'] -> [0,1]
# Out:
# parking_type: ['NS', 'NW']
# operation_type: [1, 3]
# Weekday_paid: ['N', 'Y']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# 0) 데이터 준비axis=
X = parks_df.drop(["complaints_r300", "complaint_level", "address", "lat", "lon",
                   "base_parking_fee", "base_parking_time", "additional_unit_fee", "additional_unit_time",
                   "zoning_encoded", "Weekday_start", "Weekday_end"], axis=1)
y = parks_df["complaint_level"]

# 1) 80%를 train+val, 20%를 test로 분리 (stratify 유지)
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# 2) train_val(80%) 중 12.5%를 val로 → 전체 비율 10%, train은 70%
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val,
    test_size=0.125,    # 0.8 * 0.125 = 0.1
    stratify=y_train_val,
    random_state=42
)

# 3) 훈련셋에서만 RandomForest로 피처 중요도 계산
rf_fs = RandomForestClassifier(random_state=0)
rf_fs.fit(X_train, y_train)

importances = pd.Series(rf_fs.feature_importances_, index=X_train.columns)
top10 = importances.nlargest(10).index.tolist()
print("선택된 상위 10개 피처:", top10)

if 'start_sin' in top10 and 'start_cos' not in top10:
    top10.append('start_cos')
if 'start_cos' in top10 and 'start_sin' not in top10:
    top10.append('start_sin')
# 이렇게 하면 둘이 반드시 함께 들어감


# 4) 선택된 피처로 데이터 재정의
X_train_sel = X_train[top10]
X_val_sel   = X_val[top10]
X_test_sel  = X_test[top10]

# 5) 최종 모델 학습 & 평가
rf = RandomForestClassifier(
    random_state=0,
    class_weight="balanced"   # 클래스 불균형 보정
)
rf.fit(X_train_sel, y_train)

val_pred  = rf.predict(X_val_sel)
test_pred = rf.predict(X_test_sel)

print("Validation 정확도: {:.4f}".format(accuracy_score(y_val, val_pred)))
print("Test 정확도      : {:.4f}".format(accuracy_score(y_test, test_pred)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 7
#       4 import pandas as pd
#       6 # 0) 데이터 준비axis=
# ----> 7 X = parks_df.drop(["complaints_r300", "complaint_level", "address", "lat", "lon",
#       8                    "base_parking_fee", "base_parking_time", "additional_unit_fee", "additional_unit_time",
#       9                    "zoning_encoded", "Weekday_start", "Weekday_end"], axis=1)
#      10 y = parks_df["complaint_level"]
#      12 # 1) 80%를 train+val, 20%를 test로 분리 (stratify 유지)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['Weekday_start', 'Weekday_end'] not found in axis"

# %%
# Accuracy 분석

from sklearn.metrics import classification_report, accuracy_score

print("Complaint Level (Kmeans) Classification Accuracy:", round(accuracy_score(y_test, test_pred), 3))
print(classification_report(y_test, test_pred, target_names=['Low', 'Mid', 'High']))
# Out:
# Complaint Level (Kmeans) Classification Accuracy: 0.73
#               precision    recall  f1-score   support
#
#          Low       0.85      0.88      0.86       160
#          Mid       0.60      0.55      0.58        92
#         High       0.58      0.60      0.59        55
#
#     accuracy                           0.73       307
#    macro avg       0.68      0.68      0.68       307
# weighted avg       0.73      0.73      0.73       307

# %%
importances = rf.feature_importances_
feature_names = top10  # DataFrame에서 feature 이름 추출

# 중요도 표 만들기
importance_table = pd.DataFrame({
    'feature': feature_names,
    'importance': importances
}).sort_values(by='importance', ascending=False)

importance_table
# Out:
#                   feature  importance
# 0    total_parking_spaces    0.225239
# 1                bus_r300    0.196104
# 3                   fee1H    0.175595
# 2               cctv_r300    0.155748
# 6                 end_cos    0.062120
# 5                 end_sin    0.053904
# 4  Weekday_operatingHours    0.052679
# 9          operation_type    0.026863
# 7               start_sin    0.026162
# 8               start_cos    0.025584

# %%
import numpy as np
import pandas as pd
import shap

# ── 1) 기존 mean_abs_shap 계산 (axis=0 으로 피처별 평균 절댓값 SHAP) ─────
explainer = shap.TreeExplainer(rf)
shap_vals = explainer.shap_values(X_train_sel)

mean_abs_shap = pd.DataFrame({
    f'class_{cls}': np.abs(shap_vals[cls]).mean(axis=1)
    for cls in range(len(shap_vals))
}, index=top10)

# ── 2) start_time, end_time 그룹 중요도 (Euclidean norm) 계산 ──────────
for cls in mean_abs_shap.columns:
    # start_time
    s_sin = mean_abs_shap.loc['start_sin', cls]
    s_cos = mean_abs_shap.loc['start_cos', cls]
    mean_abs_shap.loc['start_time', cls] = np.sqrt(s_sin**2 + s_cos**2)
    # end_time
    e_sin = mean_abs_shap.loc['end_sin', cls]
    e_cos = mean_abs_shap.loc['end_cos', cls]
    mean_abs_shap.loc['end_time', cls] = np.sqrt(e_sin**2 + e_cos**2)

# ── 3) sin/cos 개별 행 제거하여 그룹화된 DataFrame 구성 ────────────────
grouped_shap = mean_abs_shap.drop(
    ['start_sin','start_cos','end_sin','end_cos'],
    axis=0
)

# ── 4) 클래스별 상위 N개 피처 출력 ──────────────────────────────────
top_n = 5
for cls in grouped_shap.columns:
    print(f"\n▶ {cls} 기여도 상위 {top_n}개 피처")
    print(grouped_shap[cls].sort_values(ascending=False).head(top_n))
# Out:
# ▶ class_0 기여도 상위 5개 피처
# end_time                  0.125475
# fee1H                     0.095519
# Weekday_operatingHours    0.061782
# cctv_r300                 0.034981
# bus_r300                  0.020227
# Name: class_0, dtype: float64
#
# ▶ class_1 기여도 상위 5개 피처
# cctv_r300                 0.085584
# fee1H                     0.064939
# end_time                  0.038422
# bus_r300                  0.029805
# Weekday_operatingHours    0.022860
# Name: class_1, dtype: float64
#
# ▶ class_2 기여도 상위 5개 피처
# end_time                  0.107567
# operation_type            0.079873
# Weekday_operatingHours    0.059192
# bus_r300                  0.049385
# fee1H                     0.048628
# Name: class_2, dtype: float64
#
# ▶ class_3 기여도 상위 5개 피처
# bus_r300                  0.076570
# cctv_r300                 0.075910
# fee1H                     0.058186
# end_time                  0.057149
# Weekday_operatingHours    0.041381
# Name: class_3, dtype: float64
#
# ▶ class_4 기여도 상위 5개 피처
# cctv_r300                 0.085931
# bus_r300                  0.069947
# end_time                  0.062194
# fee1H                     0.045342
# Weekday_operatingHours    0.036068
# Name: class_4, dtype: float64
#
# ▶ class_5 기여도 상위 5개 피처
# bus_r300                0.074583
# cctv_r300               0.072891
# fee1H                   0.071462
# total_parking_spaces    0.039764
# end_time                0.029003
# Name: class_5, dtype: float64
#
# ▶ class_6 기여도 상위 5개 피처
# fee1H                   0.095128
# bus_r300                0.058428
# end_time                0.057184
# total_parking_spaces    0.050969
# cctv_r300               0.032646
# Name: class_6, dtype: float64
#
# ▶ class_7 기여도 상위 5개 피처
# end_time                  0.068249
# bus_r300                  0.067057
# Weekday_operatingHours    0.051447
# total_parking_spaces      0.040437
# start_time                0.033717
# Name: class_7, dtype: float64
#
# ▶ class_8 기여도 상위 5개 피처
# fee1H                     0.122991
# cctv_r300                 0.067419
# end_time                  0.043680
# Weekday_operatingHours    0.037111
# total_parking_spaces      0.035183
# Name: class_8, dtype: float64
#
# ▶ class_9 기여도 상위 5개 피처
# end_time                  0.128322
# fee1H                     0.098396
# Weekday_operatingHours    0.066471
# total_parking_spaces      0.022806
# bus_r300                  0.022331
# Name: class_9, dtype: float64
#
# ▶ class_10 기여도 상위 5개 피처
# Weekday_operatingHours    0.066547
# total_parking_spaces      0.065773
# end_time                  0.062491
# start_time                0.059912
# fee1H                     0.031249
# Name: class_10, dtype: float64
#
# ▶ class_11 기여도 상위 5개 피처
# cctv_r300               0.099180
# bus_r300                0.073941
# fee1H                   0.067725
# end_time                0.053645
# total_parking_spaces    0.034500
# Name: class_11, dtype: float64
#
# ▶ class_12 기여도 상위 5개 피처
# end_time                  0.123969
# total_parking_spaces      0.055690
# fee1H                     0.049072
# Weekday_operatingHours    0.036064
# start_time                0.031002
# Name: class_12, dtype: float64
#
# ▶ class_13 기여도 상위 5개 피처
# total_parking_spaces      0.113008
# bus_r300                  0.079198
# end_time                  0.066002
# cctv_r300                 0.064201
# Weekday_operatingHours    0.040801
# Name: class_13, dtype: float64
#
# ▶ class_14 기여도 상위 5개 피처
# cctv_r300               0.106633
# total_parking_spaces    0.102400
# fee1H                   0.046263
# bus_r300                0.040230
# end_time                0.038506
# Name: class_14, dtype: float64
#
# ▶ class_15 기여도 상위 5개 피처
# fee1H                   0.085695
# cctv_r300               0.076280
# total_parking_spaces    0.051228
# end_time                0.046939
# bus_r300                0.040066
# Name: class_15, dtype: float64
#
# ▶ class_16 기여도 상위 5개 피처
# fee1H                   0.182584
# cctv_r300               0.053039
# end_time                0.024156
# total_parking_spaces    0.023557
# operation_type          0.014544
# Name: class_16, dtype: float64
#
# ▶ class_17 기여도 상위 5개 피처
# total_parking_spaces      0.112928
# fee1H                     0.098966
# end_time                  0.055779
# cctv_r300                 0.055194
# Weekday_operatingHours    0.037286
# Name: class_17, dtype: float64
#
# ▶ class_18 기여도 상위 5개 피처
# end_time                0.089909
# cctv_r300               0.089433
# fee1H                   0.081445
# bus_r300                0.057654
# total_parking_spaces    0.045269
# Name: class_18, dtype: float64
#
# ▶ class_19 기여도 상위 5개 피처
# end_time                  0.135565
# fee1H                     0.112535
# Weekday_operatingHours    0.071554
# bus_r300                  0.028994
# total_parking_spaces      0.022059
# Name: class_19, dtype: float64
#
# ▶ class_20 기여도 상위 5개 피처
# fee1H                   0.121604
# total_parking_spaces    0.108039
# bus_r300                0.067773
# end_time                0.040517
# cctv_r300               0.037392
# Name: class_20, dtype: float64
#
# ▶ class_21 기여도 상위 5개 피처
# cctv_r300               0.143160
# fee1H                   0.109230
# total_parking_spaces    0.097147
# bus_r300                0.037452
# end_time                0.031210
# Name: class_21, dtype: float64
#
# ▶ class_22 기여도 상위 5개 피처
# Weekday_operatingHours    0.099800
# end_time                  0.080083
# start_time                0.055778
# fee1H                     0.051359
# total_parking_spaces      0.041257
# Name: class_22, dtype: float64
#
# ▶ class_23 기여도 상위 5개 피처
# total_parking_spaces    0.073341
# bus_r300                0.066531
# cctv_r300               0.065483
# fee1H                   0.050271
# end_time                0.049569
# Name: class_23, dtype: float64
#
# ▶ class_24 기여도 상위 5개 피처
# total_parking_spaces      0.139430
# end_time                  0.066775
# cctv_r300                 0.051096
# bus_r300                  0.047392
# Weekday_operatingHours    0.039983
# Name: class_24, dtype: float64
#
# ▶ class_25 기여도 상위 5개 피처
# total_parking_spaces    0.157555
# fee1H                   0.062326
# end_time                0.048363
# bus_r300                0.040440
# cctv_r300               0.032503
# Name: class_25, dtype: float64
#
# ▶ class_26 기여도 상위 5개 피처
# bus_r300                  0.086115
# total_parking_spaces      0.076113
# fee1H                     0.048705
# end_time                  0.044965
# Weekday_operatingHours    0.032281
# Name: class_26, dtype: float64
#
# ▶ class_27 기여도 상위 5개 피처
# total_parking_spaces    0.166599
# bus_r300                0.099963
# fee1H                   0.043942
# cctv_r300               0.026434
# end_time                0.020671
# Name: class_27, dtype: float64
#
# ▶ class_28 기여도 상위 5개 피처
# total_parking_spaces      0.068630
# end_time                  0.060930
# Weekday_operatingHours    0.045802
# start_time                0.031957
# bus_r300                  0.031672
# Name: class_28, dtype: float64
#
# ▶ class_29 기여도 상위 5개 피처
# cctv_r300                 0.076260
# end_time                  0.056533
# bus_r300                  0.054006
# total_parking_spaces      0.040738
# Weekday_operatingHours    0.040698
# Name: class_29, dtype: float64
#
# ▶ class_30 기여도 상위 5개 피처
# bus_r300                0.068604
# fee1H                   0.060294
# total_parking_spaces    0.060076
# operation_type          0.053231
# cctv_r300               0.037225
# Name: class_30, dtype: float64
#
# ▶ class_31 기여도 상위 5개 피처
# cctv_r300                 0.100949
# end_time                  0.065453
# total_parking_spaces      0.057400
# Weekday_operatingHours    0.043715
# bus_r300                  0.036780
# Name: class_31, dtype: float64
#
# ▶ class_32 기여도 상위 5개 피처
# end_time                  0.064846
# bus_r300                  0.052368
# Weekday_operatingHours    0.044474
# total_parking_spaces      0.042725
# cctv_r300                 0.039205
# Name: class_32, dtype: float64
#
# ▶ class_33 기여도 상위 5개 피처
# fee1H                   0.076265
# total_parking_spaces    0.062839
# cctv_r300               0.061515
# end_time                0.048263
# bus_r300                0.028343
# Name: class_33, dtype: float64
#
# ▶ class_34 기여도 상위 5개 피처
# total_parking_spaces      0.103910
# Weekday_operatingHours    0.083731
# end_time                  0.071529
# cctv_r300                 0.051180
# fee1H                     0.035616
# Name: class_34, dtype: float64
#
# ▶ class_35 기여도 상위 5개 피처
# fee1H                     0.092504
# cctv_r300                 0.074197
# total_parking_spaces      0.060685
# end_time                  0.051526
# Weekday_operatingHours    0.039496
# Name: class_35, dtype: float64
#
# ▶ class_36 기여도 상위 5개 피처
# fee1H                   0.145075
# cctv_r300               0.099980
# total_parking_spaces    0.019289
# end_time                0.016099
# operation_type          0.013707
# Name: class_36, dtype: float64
#
# ▶ class_37 기여도 상위 5개 피처
# end_time                  0.061884
# cctv_r300                 0.060955
# bus_r300                  0.058491
# fee1H                     0.045588
# Weekday_operatingHours    0.043232
# Name: class_37, dtype: float64
#
# ▶ class_38 기여도 상위 5개 피처
# end_time                  0.119772
# fee1H                     0.108806
# Weekday_operatingHours    0.064408
# operation_type            0.026980
# total_parking_spaces      0.025764
# Name: class_38, dtype: float64
#
# ▶ class_39 기여도 상위 5개 피처
# fee1H                     0.100841
# bus_r300                  0.100203
# Weekday_operatingHours    0.069674
# total_parking_spaces      0.058254
# end_time                  0.048220
# Name: class_39, dtype: float64
#
# ▶ class_40 기여도 상위 5개 피처
# end_time                  0.059457
# Weekday_operatingHours    0.045464
# total_parking_spaces      0.040108
# start_time                0.034014
# cctv_r300                 0.016955
# Name: class_40, dtype: float64
#
# ▶ class_41 기여도 상위 5개 피처
# cctv_r300                 0.070306
# end_time                  0.052854
# start_time                0.052656
# Weekday_operatingHours    0.049310
# bus_r300                  0.045516
# Name: class_41, dtype: float64
#
# ▶ class_42 기여도 상위 5개 피처
# end_time                  0.063846
# cctv_r300                 0.063583
# fee1H                     0.062696
# total_parking_spaces      0.043428
# Weekday_operatingHours    0.036751
# Name: class_42, dtype: float64
#
# ▶ class_43 기여도 상위 5개 피처
# cctv_r300               0.114074
# end_time                0.062372
# total_parking_spaces    0.061101
# bus_r300                0.056255
# fee1H                   0.054747
# Name: class_43, dtype: float64
#
# ▶ class_44 기여도 상위 5개 피처
# end_time                  0.121500
# total_parking_spaces      0.089340
# Weekday_operatingHours    0.077222
# fee1H                     0.046212
# bus_r300                  0.022018
# Name: class_44, dtype: float64
#
# ▶ class_45 기여도 상위 5개 피처
# bus_r300                  0.094855
# fee1H                     0.066912
# end_time                  0.055153
# total_parking_spaces      0.042945
# Weekday_operatingHours    0.034995
# Name: class_45, dtype: float64
#
# ▶ class_46 기여도 상위 5개 피처
# fee1H                     0.117191
# end_time                  0.107530
# Weekday_operatingHours    0.057100
# total_parking_spaces      0.031249
# start_time                0.017679
# Name: class_46, dtype: float64
#
# ▶ class_47 기여도 상위 5개 피처
# bus_r300                  0.140944
# cctv_r300                 0.136736
# end_time                  0.047218
# fee1H                     0.032022
# Weekday_operatingHours    0.028519
# Name: class_47, dtype: float64
#
# ▶ class_48 기여도 상위 5개 피처
# end_time                  0.119668
# fee1H                     0.085983
# total_parking_spaces      0.084211
# Weekday_operatingHours    0.064372
# operation_type            0.016073
# Name: class_48, dtype: float64
#
# ▶ class_49 기여도 상위 5개 피처
# cctv_r300               0.126167
# total_parking_spaces    0.081215
# end_time                0.068884
# fee1H                   0.053392
# operation_type          0.050848
# Name: class_49, dtype: float64
#
# ▶ class_50 기여도 상위 5개 피처
# cctv_r300                 0.069950
# total_parking_spaces      0.052270
# end_time                  0.048806
# Weekday_operatingHours    0.035026
# bus_r300                  0.034304
# Name: class_50, dtype: float64
#
# ▶ class_51 기여도 상위 5개 피처
# fee1H                     0.128936
# end_time                  0.043557
# Weekday_operatingHours    0.038461
# total_parking_spaces      0.036771
# start_time                0.027965
# Name: class_51, dtype: float64
#
# ▶ class_52 기여도 상위 5개 피처
# fee1H                     0.076113
# end_time                  0.058602
# bus_r300                  0.051236
# Weekday_operatingHours    0.036496
# total_parking_spaces      0.032796
# Name: class_52, dtype: float64
#
# ▶ class_53 기여도 상위 5개 피처
# end_time                  0.121369
# fee1H                     0.073171
# Weekday_operatingHours    0.064012
# cctv_r300                 0.050713
# bus_r300                  0.037802
# Name: class_53, dtype: float64
#
# ▶ class_54 기여도 상위 5개 피처
# fee1H                     0.082532
# end_time                  0.065299
# total_parking_spaces      0.064195
# Weekday_operatingHours    0.050574
# cctv_r300                 0.046733
# Name: class_54, dtype: float64
#
# ▶ class_55 기여도 상위 5개 피처
# total_parking_spaces    0.111973
# end_time                0.065582
# fee1H                   0.061798
# bus_r300                0.051810
# start_time              0.043946
# Name: class_55, dtype: float64
#
# ▶ class_56 기여도 상위 5개 피처
# bus_r300                  0.115652
# Weekday_operatingHours    0.068735
# start_time                0.064361
# end_time                  0.060491
# fee1H                     0.038924
# Name: class_56, dtype: float64
#
# ▶ class_57 기여도 상위 5개 피처
# end_time                  0.131550
# fee1H                     0.072679
# Weekday_operatingHours    0.067896
# cctv_r300                 0.048156
# bus_r300                  0.021740
# Name: class_57, dtype: float64
#
# ▶ class_58 기여도 상위 5개 피처
# end_time                  0.060032
# cctv_r300                 0.055553
# Weekday_operatingHours    0.044557
# total_parking_spaces      0.044234
# fee1H                     0.043420
# Name: class_58, dtype: float64
#
# ▶ class_59 기여도 상위 5개 피처
# total_parking_spaces    0.097834
# fee1H                   0.088371
# bus_r300                0.069311
# cctv_r300               0.059429
# end_time                0.042168
# Name: class_59, dtype: float64
#
# ▶ class_60 기여도 상위 5개 피처
# cctv_r300                 0.132855
# Weekday_operatingHours    0.067465
# start_time                0.060636
# end_time                  0.057043
# fee1H                     0.025135
# Name: class_60, dtype: float64
#
# ▶ class_61 기여도 상위 5개 피처
# cctv_r300                 0.104803
# bus_r300                  0.056335
# total_parking_spaces      0.054744
# end_time                  0.044345
# Weekday_operatingHours    0.018320
# Name: class_61, dtype: float64
#
# ▶ class_62 기여도 상위 5개 피처
# cctv_r300                 0.129923
# fee1H                     0.101219
# total_parking_spaces      0.069843
# end_time                  0.019893
# Weekday_operatingHours    0.010736
# Name: class_62, dtype: float64
#
# ▶ class_63 기여도 상위 5개 피처
# bus_r300                0.168964
# cctv_r300               0.125649
# total_parking_spaces    0.083342
# fee1H                   0.079356
# end_time                0.024157
# Name: class_63, dtype: float64
#
# ▶ class_64 기여도 상위 5개 피처
# bus_r300                0.141727
# total_parking_spaces    0.099757
# cctv_r300               0.091283
# end_time                0.031722
# operation_type          0.027466
# Name: class_64, dtype: float64
#
# ▶ class_65 기여도 상위 5개 피처
# total_parking_spaces    0.087785
# fee1H                   0.067994
# end_time                0.055823
# start_time              0.046839
# cctv_r300               0.038501
# Name: class_65, dtype: float64
#
# ▶ class_66 기여도 상위 5개 피처
# end_time                  0.070223
# Weekday_operatingHours    0.050764
# bus_r300                  0.042083
# cctv_r300                 0.038052
# total_parking_spaces      0.037063
# Name: class_66, dtype: float64
#
# ▶ class_67 기여도 상위 5개 피처
# total_parking_spaces    0.121590
# bus_r300                0.074864
# cctv_r300               0.072167
# fee1H                   0.069362
# operation_type          0.024211
# Name: class_67, dtype: float64
#
# ▶ class_68 기여도 상위 5개 피처
# fee1H                   0.134166
# cctv_r300               0.101294
# total_parking_spaces    0.019669
# end_time                0.017944
# operation_type          0.014084
# Name: class_68, dtype: float64
#
# ▶ class_69 기여도 상위 5개 피처
# fee1H                     0.088579
# end_time                  0.075081
# total_parking_spaces      0.058115
# bus_r300                  0.042369
# Weekday_operatingHours    0.041597
# Name: class_69, dtype: float64
#
# ▶ class_70 기여도 상위 5개 피처
# bus_r300                  0.070935
# end_time                  0.058217
# cctv_r300                 0.057002
# Weekday_operatingHours    0.041097
# fee1H                     0.033416
# Name: class_70, dtype: float64
#
# ▶ class_71 기여도 상위 5개 피처
# fee1H                   0.068164
# end_time                0.063681
# bus_r300                0.051735
# start_time              0.051558
# total_parking_spaces    0.046534
# Name: class_71, dtype: float64
#
# ▶ class_72 기여도 상위 5개 피처
# total_parking_spaces      0.092213
# end_time                  0.063904
# fee1H                     0.055859
# cctv_r300                 0.040372
# Weekday_operatingHours    0.033101
# Name: class_72, dtype: float64
#
# ▶ class_73 기여도 상위 5개 피처
# end_time                  0.125568
# fee1H                     0.108762
# Weekday_operatingHours    0.061684
# bus_r300                  0.023806
# total_parking_spaces      0.022103
# Name: class_73, dtype: float64
#
# ▶ class_74 기여도 상위 5개 피처
# fee1H                     0.108178
# bus_r300                  0.081990
# end_time                  0.074983
# Weekday_operatingHours    0.036657
# cctv_r300                 0.033455
# Name: class_74, dtype: float64
#
# ▶ class_75 기여도 상위 5개 피처
# Weekday_operatingHours    0.068464
# bus_r300                  0.068068
# end_time                  0.067520
# start_time                0.057518
# fee1H                     0.052063
# Name: class_75, dtype: float64
#
# ▶ class_76 기여도 상위 5개 피처
# fee1H                     0.141590
# end_time                  0.062889
# bus_r300                  0.048295
# Weekday_operatingHours    0.043005
# total_parking_spaces      0.034271
# Name: class_76, dtype: float64
#
# ▶ class_77 기여도 상위 5개 피처
# cctv_r300               0.136895
# fee1H                   0.136115
# bus_r300                0.101486
# total_parking_spaces    0.084373
# end_time                0.022991
# Name: class_77, dtype: float64
#
# ▶ class_78 기여도 상위 5개 피처
# fee1H                     0.127503
# end_time                  0.054554
# total_parking_spaces      0.037467
# bus_r300                  0.031970
# Weekday_operatingHours    0.028485
# Name: class_78, dtype: float64
#
# ▶ class_79 기여도 상위 5개 피처
# end_time                  0.141477
# fee1H                     0.098150
# Weekday_operatingHours    0.070695
# bus_r300                  0.018882
# start_time                0.017567
# Name: class_79, dtype: float64
#
# ▶ class_80 기여도 상위 5개 피처
# end_time                  0.128372
# fee1H                     0.079164
# Weekday_operatingHours    0.066942
# cctv_r300                 0.050989
# operation_type            0.020878
# Name: class_80, dtype: float64
#
# ▶ class_81 기여도 상위 5개 피처
# end_time                  0.068436
# total_parking_spaces      0.048001
# Weekday_operatingHours    0.033244
# bus_r300                  0.030170
# start_time                0.029613
# Name: class_81, dtype: float64
#
# ▶ class_82 기여도 상위 5개 피처
# cctv_r300                 0.177096
# Weekday_operatingHours    0.063652
# start_time                0.062423
# end_time                  0.047425
# fee1H                     0.019795
# Name: class_82, dtype: float64
#
# ▶ class_83 기여도 상위 5개 피처
# total_parking_spaces      0.130006
# end_time                  0.054068
# bus_r300                  0.047208
# fee1H                     0.046307
# Weekday_operatingHours    0.025871
# Name: class_83, dtype: float64
#
# ▶ class_84 기여도 상위 5개 피처
# fee1H                     0.094365
# end_time                  0.071058
# Weekday_operatingHours    0.064606
# start_time                0.052349
# total_parking_spaces      0.047638
# Name: class_84, dtype: float64
#
# ▶ class_85 기여도 상위 5개 피처
# end_time                  0.089987
# Weekday_operatingHours    0.089664
# start_time                0.086652
# cctv_r300                 0.045075
# fee1H                     0.040047
# Name: class_85, dtype: float64
#
# ▶ class_86 기여도 상위 5개 피처
# total_parking_spaces      0.082424
# bus_r300                  0.071041
# cctv_r300                 0.061087
# end_time                  0.058371
# Weekday_operatingHours    0.048270
# Name: class_86, dtype: float64
#
# ▶ class_87 기여도 상위 5개 피처
# fee1H                     0.114352
# end_time                  0.054574
# cctv_r300                 0.053627
# Weekday_operatingHours    0.043644
# total_parking_spaces      0.039258
# Name: class_87, dtype: float64
#
# ▶ class_88 기여도 상위 5개 피처
# end_time                  0.088986
# Weekday_operatingHours    0.088673
# bus_r300                  0.069445
# start_time                0.050010
# cctv_r300                 0.032930
# Name: class_88, dtype: float64
#
# ▶ class_89 기여도 상위 5개 피처
# cctv_r300                 0.076623
# total_parking_spaces      0.061669
# end_time                  0.057555
# Weekday_operatingHours    0.038236
# bus_r300                  0.035448
# Name: class_89, dtype: float64
#
# ▶ class_90 기여도 상위 5개 피처
# cctv_r300                 0.116326
# end_time                  0.062966
# total_parking_spaces      0.046317
# Weekday_operatingHours    0.041761
# bus_r300                  0.032095
# Name: class_90, dtype: float64
#
# ▶ class_91 기여도 상위 5개 피처
# cctv_r300                 0.077708
# end_time                  0.077492
# Weekday_operatingHours    0.055464
# total_parking_spaces      0.052114
# bus_r300                  0.051848
# Name: class_91, dtype: float64
#
# ▶ class_92 기여도 상위 5개 피처
# end_time                  0.074285
# total_parking_spaces      0.065140
# cctv_r300                 0.062501
# Weekday_operatingHours    0.040289
# bus_r300                  0.035580
# Name: class_92, dtype: float64
#
# ▶ class_93 기여도 상위 5개 피처
# cctv_r300                 0.087929
# fee1H                     0.082858
# end_time                  0.050265
# bus_r300                  0.047974
# Weekday_operatingHours    0.022373
# Name: class_93, dtype: float64
#
# ▶ class_94 기여도 상위 5개 피처
# end_time                  0.073099
# Weekday_operatingHours    0.046361
# total_parking_spaces      0.045044
# cctv_r300                 0.042171
# fee1H                     0.042146
# Name: class_94, dtype: float64
#
# ▶ class_95 기여도 상위 5개 피처
# end_time                  0.156950
# Weekday_operatingHours    0.089066
# bus_r300                  0.031501
# cctv_r300                 0.029503
# total_parking_spaces      0.025331
# Name: class_95, dtype: float64
#
# ▶ class_96 기여도 상위 5개 피처
# bus_r300                0.168066
# fee1H                   0.088301
# total_parking_spaces    0.056447
# cctv_r300               0.044263
# end_time                0.019864
# Name: class_96, dtype: float64
#
# ▶ class_97 기여도 상위 5개 피처
# end_time                  0.071119
# start_time                0.059128
# bus_r300                  0.051788
# total_parking_spaces      0.046974
# Weekday_operatingHours    0.040255
# Name: class_97, dtype: float64
#
# ▶ class_98 기여도 상위 5개 피처
# fee1H                     0.062898
# bus_r300                  0.062848
# total_parking_spaces      0.061368
# end_time                  0.054175
# Weekday_operatingHours    0.026765
# Name: class_98, dtype: float64
#
# ▶ class_99 기여도 상위 5개 피처
# end_time                  0.124160
# fee1H                     0.098878
# Weekday_operatingHours    0.062433
# total_parking_spaces      0.028106
# bus_r300                  0.025682
# Name: class_99, dtype: float64
#
# ▶ class_100 기여도 상위 5개 피처
# fee1H                   0.070669
# cctv_r300               0.055045
# total_parking_spaces    0.050877
# end_time                0.049240
# bus_r300                0.039574
# Name: class_100, dtype: float64
#
# ▶ class_101 기여도 상위 5개 피처
# fee1H                     0.085341
# end_time                  0.063208
# cctv_r300                 0.033755
# Weekday_operatingHours    0.033582
# total_parking_spaces      0.032590
# Name: class_101, dtype: float64
#
# ▶ class_102 기여도 상위 5개 피처
# bus_r300                0.078390
# start_time              0.046065
# end_time                0.043677
# total_parking_spaces    0.041789
# fee1H                   0.036823
# Name: class_102, dtype: float64
#
# ▶ class_103 기여도 상위 5개 피처
# end_time                  0.066973
# cctv_r300                 0.053430
# Weekday_operatingHours    0.042062
# fee1H                     0.040798
# bus_r300                  0.033586
# Name: class_103, dtype: float64
#
# ▶ class_104 기여도 상위 5개 피처
# end_time                  0.121196
# fee1H                     0.110593
# Weekday_operatingHours    0.064148
# operation_type            0.030915
# bus_r300                  0.026222
# Name: class_104, dtype: float64
#
# ▶ class_105 기여도 상위 5개 피처
# bus_r300                0.110540
# total_parking_spaces    0.094664
# start_time              0.050316
# fee1H                   0.043749
# end_time                0.039380
# Name: class_105, dtype: float64
#
# ▶ class_106 기여도 상위 5개 피처
# cctv_r300               0.121581
# fee1H                   0.095407
# bus_r300                0.064757
# total_parking_spaces    0.062939
# end_time                0.024804
# Name: class_106, dtype: float64
#
# ▶ class_107 기여도 상위 5개 피처
# end_time                  0.059984
# total_parking_spaces      0.053349
# cctv_r300                 0.048253
# bus_r300                  0.042939
# Weekday_operatingHours    0.042064
# Name: class_107, dtype: float64
#
# ▶ class_108 기여도 상위 5개 피처
# fee1H                     0.078006
# end_time                  0.064697
# cctv_r300                 0.057286
# Weekday_operatingHours    0.035122
# bus_r300                  0.033134
# Name: class_108, dtype: float64
#
# ▶ class_109 기여도 상위 5개 피처
# fee1H                   0.116015
# cctv_r300               0.113809
# total_parking_spaces    0.103159
# bus_r300                0.068720
# end_time                0.023460
# Name: class_109, dtype: float64
#
# ▶ class_110 기여도 상위 5개 피처
# cctv_r300               0.118552
# total_parking_spaces    0.089052
# end_time                0.076988
# fee1H                   0.066464
# start_time              0.048064
# Name: class_110, dtype: float64
#
# ▶ class_111 기여도 상위 5개 피처
# end_time                  0.147515
# fee1H                     0.061520
# start_time                0.041820
# Weekday_operatingHours    0.035606
# total_parking_spaces      0.030742
# Name: class_111, dtype: float64
#
# ▶ class_112 기여도 상위 5개 피처
# fee1H                     0.148619
# end_time                  0.044188
# bus_r300                  0.040298
# cctv_r300                 0.034934
# Weekday_operatingHours    0.033753
# Name: class_112, dtype: float64
#
# ▶ class_113 기여도 상위 5개 피처
# fee1H                     0.107358
# end_time                  0.048896
# bus_r300                  0.047822
# total_parking_spaces      0.042030
# Weekday_operatingHours    0.039594
# Name: class_113, dtype: float64
#
# ▶ class_114 기여도 상위 5개 피처
# total_parking_spaces    0.094806
# fee1H                   0.088200
# bus_r300                0.074288
# cctv_r300               0.058859
# end_time                0.041573
# Name: class_114, dtype: float64
#
# ▶ class_115 기여도 상위 5개 피처
# bus_r300                0.136597
# fee1H                   0.078602
# end_time                0.060650
# total_parking_spaces    0.045278
# cctv_r300               0.044371
# Name: class_115, dtype: float64
#
# ▶ class_116 기여도 상위 5개 피처
# cctv_r300                 0.116023
# end_time                  0.066300
# total_parking_spaces      0.061528
# Weekday_operatingHours    0.040556
# bus_r300                  0.038706
# Name: class_116, dtype: float64
#
# ▶ class_117 기여도 상위 5개 피처
# total_parking_spaces    0.292409
# bus_r300                0.059849
# cctv_r300               0.043401
# fee1H                   0.030068
# end_time                0.021826
# Name: class_117, dtype: float64
#
# ▶ class_118 기여도 상위 5개 피처
# end_time                  0.165475
# Weekday_operatingHours    0.093376
# bus_r300                  0.026095
# total_parking_spaces      0.025334
# cctv_r300                 0.022186
# Name: class_118, dtype: float64
#
# ▶ class_119 기여도 상위 5개 피처
# fee1H                   0.139659
# end_time                0.052222
# cctv_r300               0.033660
# total_parking_spaces    0.033477
# bus_r300                0.031345
# Name: class_119, dtype: float64
#
# ▶ class_120 기여도 상위 5개 피처
# Weekday_operatingHours    0.082935
# cctv_r300                 0.072424
# start_time                0.071497
# end_time                  0.063601
# fee1H                     0.043458
# Name: class_120, dtype: float64
#
# ▶ class_121 기여도 상위 5개 피처
# cctv_r300               0.072843
# fee1H                   0.070407
# total_parking_spaces    0.067547
# bus_r300                0.039388
# end_time                0.031414
# Name: class_121, dtype: float64
#
# ▶ class_122 기여도 상위 5개 피처
# total_parking_spaces    0.176380
# bus_r300                0.122601
# fee1H                   0.055610
# cctv_r300               0.039493
# end_time                0.029878
# Name: class_122, dtype: float64
#
# ▶ class_123 기여도 상위 5개 피처
# end_time                  0.110296
# Weekday_operatingHours    0.057313
# total_parking_spaces      0.050490
# cctv_r300                 0.048576
# bus_r300                  0.032385
# Name: class_123, dtype: float64
#
# ▶ class_124 기여도 상위 5개 피처
# bus_r300                  0.154377
# end_time                  0.064400
# Weekday_operatingHours    0.061544
# start_time                0.050578
# fee1H                     0.020057
# Name: class_124, dtype: float64
#
# ▶ class_125 기여도 상위 5개 피처
# fee1H                   0.103288
# total_parking_spaces    0.090113
# bus_r300                0.081848
# cctv_r300               0.079704
# end_time                0.027018
# Name: class_125, dtype: float64
#
# ▶ class_126 기여도 상위 5개 피처
# fee1H                   0.120688
# total_parking_spaces    0.096944
# bus_r300                0.061146
# end_time                0.042143
# cctv_r300               0.040342
# Name: class_126, dtype: float64
#
# ▶ class_127 기여도 상위 5개 피처
# bus_r300                  0.107247
# end_time                  0.060432
# fee1H                     0.055623
# cctv_r300                 0.053215
# Weekday_operatingHours    0.040941
# Name: class_127, dtype: float64
#
# ▶ class_128 기여도 상위 5개 피처
# cctv_r300                 0.111009
# end_time                  0.065847
# fee1H                     0.064116
# Weekday_operatingHours    0.056005
# start_time                0.034834
# Name: class_128, dtype: float64
#
# ▶ class_129 기여도 상위 5개 피처
# total_parking_spaces      0.107975
# cctv_r300                 0.105040
# bus_r300                  0.104174
# end_time                  0.036833
# Weekday_operatingHours    0.020877
# Name: class_129, dtype: float64
#
# ▶ class_130 기여도 상위 5개 피처
# end_time                  0.119169
# cctv_r300                 0.103308
# Weekday_operatingHours    0.069823
# bus_r300                  0.033274
# fee1H                     0.021686
# Name: class_130, dtype: float64
#
# ▶ class_131 기여도 상위 5개 피처
# fee1H                   0.151881
# cctv_r300               0.084140
# bus_r300                0.058734
# total_parking_spaces    0.029572
# end_time                0.023681
# Name: class_131, dtype: float64
#
# ▶ class_132 기여도 상위 5개 피처
# cctv_r300                 0.111681
# end_time                  0.054831
# bus_r300                  0.048101
# total_parking_spaces      0.042792
# Weekday_operatingHours    0.036593
# Name: class_132, dtype: float64
#
# ▶ class_133 기여도 상위 5개 피처
# fee1H                     0.144242
# end_time                  0.069387
# total_parking_spaces      0.068317
# cctv_r300                 0.043461
# Weekday_operatingHours    0.033315
# Name: class_133, dtype: float64
#
# ▶ class_134 기여도 상위 5개 피처
# end_time                  0.142109
# fee1H                     0.113120
# Weekday_operatingHours    0.063114
# total_parking_spaces      0.023221
# bus_r300                  0.018588
# Name: class_134, dtype: float64
#
# ▶ class_135 기여도 상위 5개 피처
# end_time                  0.117226
# total_parking_spaces      0.069673
# fee1H                     0.058491
# Weekday_operatingHours    0.039890
# start_time                0.024202
# Name: class_135, dtype: float64
#
# ▶ class_136 기여도 상위 5개 피처
# end_time                  0.060333
# fee1H                     0.059298
# cctv_r300                 0.055975
# Weekday_operatingHours    0.033295
# start_time                0.019871
# Name: class_136, dtype: float64
#
# ▶ class_137 기여도 상위 5개 피처
# end_time                  0.095194
# cctv_r300                 0.083790
# total_parking_spaces      0.069948
# Weekday_operatingHours    0.047089
# start_time                0.046693
# Name: class_137, dtype: float64
#
# ▶ class_138 기여도 상위 5개 피처
# end_time                  0.125721
# cctv_r300                 0.078967
# fee1H                     0.066767
# Weekday_operatingHours    0.063704
# operation_type            0.015267
# Name: class_138, dtype: float64
#
# ▶ class_139 기여도 상위 5개 피처
# end_time                  0.139411
# fee1H                     0.100946
# Weekday_operatingHours    0.068096
# operation_type            0.023543
# bus_r300                  0.014717
# Name: class_139, dtype: float64
#
# ▶ class_140 기여도 상위 5개 피처
# total_parking_spaces      0.073213
# end_time                  0.067893
# start_time                0.059536
# Weekday_operatingHours    0.053105
# fee1H                     0.049879
# Name: class_140, dtype: float64
#
# ▶ class_141 기여도 상위 5개 피처
# total_parking_spaces    0.069996
# fee1H                   0.069358
# end_time                0.068262
# cctv_r300               0.061210
# bus_r300                0.054612
# Name: class_141, dtype: float64
#
# ▶ class_142 기여도 상위 5개 피처
# bus_r300                0.100194
# total_parking_spaces    0.094403
# end_time                0.082110
# fee1H                   0.061138
# start_time              0.044348
# Name: class_142, dtype: float64
#
# ▶ class_143 기여도 상위 5개 피처
# fee1H                     0.105391
# total_parking_spaces      0.075780
# end_time                  0.070219
# cctv_r300                 0.047124
# Weekday_operatingHours    0.042492
# Name: class_143, dtype: float64
#
# ▶ class_144 기여도 상위 5개 피처
# end_time                  0.133630
# fee1H                     0.102620
# Weekday_operatingHours    0.062939
# total_parking_spaces      0.023491
# bus_r300                  0.021503
# Name: class_144, dtype: float64
#
# ▶ class_145 기여도 상위 5개 피처
# end_time                  0.137446
# fee1H                     0.110324
# Weekday_operatingHours    0.072318
# operation_type            0.020158
# start_time                0.016851
# Name: class_145, dtype: float64
#
# ▶ class_146 기여도 상위 5개 피처
# fee1H                     0.084881
# Weekday_operatingHours    0.071723
# start_time                0.070973
# end_time                  0.067335
# cctv_r300                 0.046314
# Name: class_146, dtype: float64
#
# ▶ class_147 기여도 상위 5개 피처
# total_parking_spaces      0.107975
# cctv_r300                 0.105040
# bus_r300                  0.104174
# end_time                  0.036833
# Weekday_operatingHours    0.020877
# Name: class_147, dtype: float64
#
# ▶ class_148 기여도 상위 5개 피처
# fee1H                   0.098389
# total_parking_spaces    0.084377
# cctv_r300               0.067360
# bus_r300                0.058821
# end_time                0.031297
# Name: class_148, dtype: float64
#
# ▶ class_149 기여도 상위 5개 피처
# cctv_r300               0.123192
# total_parking_spaces    0.073564
# bus_r300                0.066821
# fee1H                   0.061682
# end_time                0.032668
# Name: class_149, dtype: float64
#
# ▶ class_150 기여도 상위 5개 피처
# total_parking_spaces      0.087403
# cctv_r300                 0.058774
# end_time                  0.049188
# bus_r300                  0.046835
# Weekday_operatingHours    0.033919
# Name: class_150, dtype: float64
#
# ▶ class_151 기여도 상위 5개 피처
# total_parking_spaces    0.149441
# bus_r300                0.122844
# fee1H                   0.078389
# end_time                0.027707
# cctv_r300               0.026642
# Name: class_151, dtype: float64
#
# ▶ class_152 기여도 상위 5개 피처
# end_time                  0.116312
# cctv_r300                 0.071453
# Weekday_operatingHours    0.062990
# fee1H                     0.048985
# bus_r300                  0.046579
# Name: class_152, dtype: float64
#
# ▶ class_153 기여도 상위 5개 피처
# cctv_r300               0.068921
# end_time                0.042435
# fee1H                   0.041170
# bus_r300                0.035495
# total_parking_spaces    0.033679
# Name: class_153, dtype: float64
#
# ▶ class_154 기여도 상위 5개 피처
# end_time                  0.114805
# fee1H                     0.100307
# Weekday_operatingHours    0.058228
# bus_r300                  0.052924
# operation_type            0.034938
# Name: class_154, dtype: float64
#
# ▶ class_155 기여도 상위 5개 피처
# end_time                  0.142321
# Weekday_operatingHours    0.072719
# cctv_r300                 0.046505
# fee1H                     0.045019
# bus_r300                  0.040875
# Name: class_155, dtype: float64
#
# ▶ class_156 기여도 상위 5개 피처
# total_parking_spaces    0.121641
# fee1H                   0.068496
# end_time                0.066044
# start_time              0.044476
# bus_r300                0.043500
# Name: class_156, dtype: float64
#
# ▶ class_157 기여도 상위 5개 피처
# end_time                  0.060288
# fee1H                     0.049737
# total_parking_spaces      0.041034
# Weekday_operatingHours    0.040310
# cctv_r300                 0.040000
# Name: class_157, dtype: float64
#
# ▶ class_158 기여도 상위 5개 피처
# end_time                  0.125335
# fee1H                     0.094287
# Weekday_operatingHours    0.061885
# bus_r300                  0.029843
# operation_type            0.024369
# Name: class_158, dtype: float64
#
# ▶ class_159 기여도 상위 5개 피처
# end_time                  0.140221
# fee1H                     0.087548
# Weekday_operatingHours    0.068913
# bus_r300                  0.021793
# operation_type            0.021671
# Name: class_159, dtype: float64
#
# ▶ class_160 기여도 상위 5개 피처
# cctv_r300                 0.121797
# fee1H                     0.096933
# bus_r300                  0.079106
# total_parking_spaces      0.079055
# Weekday_operatingHours    0.023930
# Name: class_160, dtype: float64
#
# ▶ class_161 기여도 상위 5개 피처
# bus_r300                  0.103919
# Weekday_operatingHours    0.072320
# start_time                0.055444
# end_time                  0.054848
# fee1H                     0.043162
# Name: class_161, dtype: float64
#
# ▶ class_162 기여도 상위 5개 피처
# bus_r300                  0.107247
# end_time                  0.060432
# fee1H                     0.055623
# cctv_r300                 0.053215
# Weekday_operatingHours    0.040941
# Name: class_162, dtype: float64
#
# ▶ class_163 기여도 상위 5개 피처
# bus_r300                  0.082333
# total_parking_spaces      0.065934
# cctv_r300                 0.064014
# end_time                  0.062104
# Weekday_operatingHours    0.047988
# Name: class_163, dtype: float64
#
# ▶ class_164 기여도 상위 5개 피처
# total_parking_spaces      0.103910
# Weekday_operatingHours    0.083731
# end_time                  0.071529
# cctv_r300                 0.051180
# fee1H                     0.035616
# Name: class_164, dtype: float64
#
# ▶ class_165 기여도 상위 5개 피처
# end_time                  0.080417
# bus_r300                  0.075732
# fee1H                     0.057336
# Weekday_operatingHours    0.052105
# cctv_r300                 0.019393
# Name: class_165, dtype: float64
#
# ▶ class_166 기여도 상위 5개 피처
# fee1H                   0.107218
# bus_r300                0.092274
# total_parking_spaces    0.075851
# cctv_r300               0.051855
# end_time                0.020949
# Name: class_166, dtype: float64
#
# ▶ class_167 기여도 상위 5개 피처
# fee1H                     0.092383
# bus_r300                  0.081727
# total_parking_spaces      0.061197
# end_time                  0.047995
# Weekday_operatingHours    0.035760
# Name: class_167, dtype: float64
#
# ▶ class_168 기여도 상위 5개 피처
# total_parking_spaces    0.259906
# bus_r300                0.069520
# fee1H                   0.053478
# cctv_r300               0.045505
# end_time                0.021770
# Name: class_168, dtype: float64
#
# ▶ class_169 기여도 상위 5개 피처
# end_time                  0.143366
# total_parking_spaces      0.039888
# start_time                0.039731
# Weekday_operatingHours    0.035931
# bus_r300                  0.023984
# Name: class_169, dtype: float64
#
# ▶ class_170 기여도 상위 5개 피처
# end_time                  0.138864
# fee1H                     0.117472
# Weekday_operatingHours    0.070538
# bus_r300                  0.026007
# total_parking_spaces      0.018282
# Name: class_170, dtype: float64
#
# ▶ class_171 기여도 상위 5개 피처
# cctv_r300                 0.116023
# end_time                  0.066300
# total_parking_spaces      0.061528
# Weekday_operatingHours    0.040556
# bus_r300                  0.038706
# Name: class_171, dtype: float64
#
# ▶ class_172 기여도 상위 5개 피처
# total_parking_spaces      0.075545
# bus_r300                  0.065746
# end_time                  0.054013
# fee1H                     0.053040
# Weekday_operatingHours    0.042685
# Name: class_172, dtype: float64
#
# ▶ class_173 기여도 상위 5개 피처
# cctv_r300                 0.101797
# bus_r300                  0.074798
# total_parking_spaces      0.061818
# end_time                  0.054843
# Weekday_operatingHours    0.032534
# Name: class_173, dtype: float64
#
# ▶ class_174 기여도 상위 5개 피처
# end_time                  0.107337
# cctv_r300                 0.065904
# Weekday_operatingHours    0.063356
# start_time                0.023773
# fee1H                     0.020361
# Name: class_174, dtype: float64
#
# ▶ class_175 기여도 상위 5개 피처
# cctv_r300                 0.103355
# end_time                  0.063445
# Weekday_operatingHours    0.043099
# bus_r300                  0.037727
# fee1H                     0.037141
# Name: class_175, dtype: float64
#
# ▶ class_176 기여도 상위 5개 피처
# total_parking_spaces    0.123877
# cctv_r300               0.090875
# bus_r300                0.089388
# fee1H                   0.044800
# end_time                0.032221
# Name: class_176, dtype: float64
#
# ▶ class_177 기여도 상위 5개 피처
# end_time                  0.103665
# bus_r300                  0.094275
# total_parking_spaces      0.076209
# Weekday_operatingHours    0.063227
# cctv_r300                 0.028768
# Name: class_177, dtype: float64
#
# ▶ class_178 기여도 상위 5개 피처
# bus_r300                  0.129549
# cctv_r300                 0.125842
# fee1H                     0.055240
# end_time                  0.039228
# Weekday_operatingHours    0.024352
# Name: class_178, dtype: float64
#
# ▶ class_179 기여도 상위 5개 피처
# end_time                  0.139044
# fee1H                     0.095362
# Weekday_operatingHours    0.070001
# operation_type            0.019259
# bus_r300                  0.016328
# Name: class_179, dtype: float64
#
# ▶ class_180 기여도 상위 5개 피처
# bus_r300                0.061572
# cctv_r300               0.058932
# total_parking_spaces    0.056126
# end_time                0.055861
# fee1H                   0.054595
# Name: class_180, dtype: float64
#
# ▶ class_181 기여도 상위 5개 피처
# end_time                  0.126304
# fee1H                     0.088027
# Weekday_operatingHours    0.062336
# bus_r300                  0.047858
# operation_type            0.016159
# Name: class_181, dtype: float64
#
# ▶ class_182 기여도 상위 5개 피처
# cctv_r300                 0.129489
# total_parking_spaces      0.068741
# fee1H                     0.063479
# end_time                  0.054057
# Weekday_operatingHours    0.030292
# Name: class_182, dtype: float64
#
# ▶ class_183 기여도 상위 5개 피처
# total_parking_spaces    0.089476
# end_time                0.054055
# bus_r300                0.050415
# cctv_r300               0.049619
# fee1H                   0.049518
# Name: class_183, dtype: float64
#
# ▶ class_184 기여도 상위 5개 피처
# total_parking_spaces      0.081760
# fee1H                     0.075808
# end_time                  0.064358
# cctv_r300                 0.043632
# Weekday_operatingHours    0.035047
# Name: class_184, dtype: float64
#
# ▶ class_185 기여도 상위 5개 피처
# cctv_r300                 0.146633
# bus_r300                  0.087036
# end_time                  0.064078
# total_parking_spaces      0.049265
# Weekday_operatingHours    0.037190
# Name: class_185, dtype: float64
#
# ▶ class_186 기여도 상위 5개 피처
# total_parking_spaces    0.121590
# bus_r300                0.074864
# cctv_r300               0.072167
# fee1H                   0.069362
# operation_type          0.024211
# Name: class_186, dtype: float64
#
# ▶ class_187 기여도 상위 5개 피처
# end_time                  0.119169
# fee1H                     0.090100
# bus_r300                  0.065263
# Weekday_operatingHours    0.057700
# operation_type            0.023198
# Name: class_187, dtype: float64
#
# ▶ class_188 기여도 상위 5개 피처
# total_parking_spaces      0.154639
# Weekday_operatingHours    0.060192
# end_time                  0.057720
# start_time                0.052722
# fee1H                     0.044050
# Name: class_188, dtype: float64
#
# ▶ class_189 기여도 상위 5개 피처
# end_time                  0.089174
# cctv_r300                 0.084152
# fee1H                     0.077988
# Weekday_operatingHours    0.057240
# bus_r300                  0.055498
# Name: class_189, dtype: float64
#
# ▶ class_190 기여도 상위 5개 피처
# bus_r300                  0.130640
# Weekday_operatingHours    0.072296
# end_time                  0.067535
# start_time                0.051988
# cctv_r300                 0.032912
# Name: class_190, dtype: float64
#
# ▶ class_191 기여도 상위 5개 피처
# fee1H                     0.109577
# end_time                  0.046043
# Weekday_operatingHours    0.042396
# total_parking_spaces      0.037676
# start_time                0.036043
# Name: class_191, dtype: float64
#
# ▶ class_192 기여도 상위 5개 피처
# bus_r300                  0.085230
# end_time                  0.058063
# cctv_r300                 0.054887
# fee1H                     0.040919
# Weekday_operatingHours    0.039627
# Name: class_192, dtype: float64
#
# ▶ class_193 기여도 상위 5개 피처
# fee1H                     0.067478
# total_parking_spaces      0.064206
# end_time                  0.057904
# cctv_r300                 0.042899
# Weekday_operatingHours    0.037527
# Name: class_193, dtype: float64
#
# ▶ class_194 기여도 상위 5개 피처
# total_parking_spaces      0.081436
# bus_r300                  0.067281
# cctv_r300                 0.052694
# end_time                  0.050441
# Weekday_operatingHours    0.041042
# Name: class_194, dtype: float64
#
# ▶ class_195 기여도 상위 5개 피처
# fee1H                     0.079774
# end_time                  0.054490
# total_parking_spaces      0.047594
# Weekday_operatingHours    0.041649
# bus_r300                  0.041313
# Name: class_195, dtype: float64
#
# ▶ class_196 기여도 상위 5개 피처
# end_time                  0.083322
# bus_r300                  0.077169
# Weekday_operatingHours    0.070685
# fee1H                     0.047926
# total_parking_spaces      0.046482
# Name: class_196, dtype: float64
#
# ▶ class_197 기여도 상위 5개 피처
# cctv_r300                 0.144046
# end_time                  0.055943
# fee1H                     0.051856
# total_parking_spaces      0.047982
# Weekday_operatingHours    0.035830
# Name: class_197, dtype: float64
#
# ▶ class_198 기여도 상위 5개 피처
# end_time                  0.133183
# fee1H                     0.098893
# Weekday_operatingHours    0.068034
# total_parking_spaces      0.030054
# bus_r300                  0.020364
# Name: class_198, dtype: float64
#
# ▶ class_199 기여도 상위 5개 피처
# end_time                  0.130746
# Weekday_operatingHours    0.062614
# cctv_r300                 0.041459
# operation_type            0.037862
# bus_r300                  0.032249
# Name: class_199, dtype: float64
#
# ▶ class_200 기여도 상위 5개 피처
# cctv_r300                 0.063938
# end_time                  0.044140
# total_parking_spaces      0.039307
# fee1H                     0.031025
# Weekday_operatingHours    0.026536
# Name: class_200, dtype: float64
#
# ▶ class_201 기여도 상위 5개 피처
# fee1H                     0.070297
# end_time                  0.056252
# Weekday_operatingHours    0.035037
# total_parking_spaces      0.030356
# bus_r300                  0.028337
# Name: class_201, dtype: float64
#
# ▶ class_202 기여도 상위 5개 피처
# total_parking_spaces    0.149580
# fee1H                   0.096849
# bus_r300                0.086786
# cctv_r300               0.035589
# start_time              0.013326
# Name: class_202, dtype: float64
#
# ▶ class_203 기여도 상위 5개 피처
# cctv_r300                 0.125483
# end_time                  0.073697
# total_parking_spaces      0.063654
# Weekday_operatingHours    0.044882
# fee1H                     0.042878
# Name: class_203, dtype: float64
#
# ▶ class_204 기여도 상위 5개 피처
# total_parking_spaces      0.065795
# bus_r300                  0.055466
# end_time                  0.055176
# Weekday_operatingHours    0.053375
# start_time                0.051202
# Name: class_204, dtype: float64
#
# ▶ class_205 기여도 상위 5개 피처
# bus_r300                0.200406
# total_parking_spaces    0.081951
# fee1H                   0.070737
# cctv_r300               0.037802
# end_time                0.021761
# Name: class_205, dtype: float64
#
# ▶ class_206 기여도 상위 5개 피처
# total_parking_spaces      0.117474
# end_time                  0.064607
# cctv_r300                 0.063287
# bus_r300                  0.062011
# Weekday_operatingHours    0.047866
# Name: class_206, dtype: float64
#
# ▶ class_207 기여도 상위 5개 피처
# cctv_r300                 0.094841
# Weekday_operatingHours    0.073778
# bus_r300                  0.067954
# start_time                0.059582
# end_time                  0.059396
# Name: class_207, dtype: float64
#
# ▶ class_208 기여도 상위 5개 피처
# fee1H                     0.109577
# end_time                  0.046043
# Weekday_operatingHours    0.042396
# total_parking_spaces      0.037676
# start_time                0.036043
# Name: class_208, dtype: float64
#
# ▶ class_209 기여도 상위 5개 피처
# bus_r300                0.110540
# total_parking_spaces    0.094664
# ...
# end_time                  0.108778
# Weekday_operatingHours    0.058680
# bus_r300                  0.046116
# total_parking_spaces      0.044608
# cctv_r300                 0.043138
# Name: class_1002, dtype: float64
#
# ▶ class_1003 기여도 상위 5개 피처
# bus_r300                  0.186547
# cctv_r300                 0.123796
# fee1H                     0.050094
# total_parking_spaces      0.042523
# Weekday_operatingHours    0.018411
# Name: class_1003, dtype: float64
#
# ▶ class_1004 기여도 상위 5개 피처
# fee1H                     0.085021
# end_time                  0.053274
# Weekday_operatingHours    0.041852
# cctv_r300                 0.032347
# bus_r300                  0.030235
# Name: class_1004, dtype: float64
#
# ▶ class_1005 기여도 상위 5개 피처
# end_time                  0.116464
# fee1H                     0.069365
# Weekday_operatingHours    0.061653
# bus_r300                  0.057828
# cctv_r300                 0.054793
# Name: class_1005, dtype: float64
#
# ▶ class_1006 기여도 상위 5개 피처
# fee1H                   0.193361
# cctv_r300               0.039865
# total_parking_spaces    0.019413
# end_time                0.017443
# bus_r300                0.016603
# Name: class_1006, dtype: float64
#
# ▶ class_1007 기여도 상위 5개 피처
# fee1H                     0.108829
# operation_type            0.080623
# end_time                  0.077166
# total_parking_spaces      0.035405
# Weekday_operatingHours    0.034783
# Name: class_1007, dtype: float64
#
# ▶ class_1008 기여도 상위 5개 피처
# cctv_r300                 0.149785
# total_parking_spaces      0.061744
# end_time                  0.058097
# fee1H                     0.047644
# Weekday_operatingHours    0.034316
# Name: class_1008, dtype: float64
#
# ▶ class_1009 기여도 상위 5개 피처
# end_time                  0.119374
# fee1H                     0.096863
# total_parking_spaces      0.084197
# Weekday_operatingHours    0.058456
# start_time                0.013926
# Name: class_1009, dtype: float64
#
# ▶ class_1010 기여도 상위 5개 피처
# end_time                  0.108899
# cctv_r300                 0.089663
# Weekday_operatingHours    0.061290
# bus_r300                  0.041459
# total_parking_spaces      0.038019
# Name: class_1010, dtype: float64
#
# ▶ class_1011 기여도 상위 5개 피처
# total_parking_spaces      0.058701
# end_time                  0.051214
# bus_r300                  0.047150
# cctv_r300                 0.043552
# Weekday_operatingHours    0.039393
# Name: class_1011, dtype: float64
#
# ▶ class_1012 기여도 상위 5개 피처
# end_time                  0.071067
# total_parking_spaces      0.064107
# Weekday_operatingHours    0.039471
# cctv_r300                 0.034968
# bus_r300                  0.034315
# Name: class_1012, dtype: float64
#
# ▶ class_1013 기여도 상위 5개 피처
# bus_r300                  0.088425
# Weekday_operatingHours    0.077089
# end_time                  0.066685
# start_time                0.063569
# fee1H                     0.048643
# Name: class_1013, dtype: float64
#
# ▶ class_1014 기여도 상위 5개 피처
# cctv_r300                 0.107451
# bus_r300                  0.064180
# fee1H                     0.063903
# Weekday_operatingHours    0.054421
# end_time                  0.048298
# Name: class_1014, dtype: float64
#
# ▶ class_1015 기여도 상위 5개 피처
# end_time                  0.058377
# Weekday_operatingHours    0.047869
# bus_r300                  0.036753
# cctv_r300                 0.034641
# total_parking_spaces      0.034150
# Name: class_1015, dtype: float64
#
# ▶ class_1016 기여도 상위 5개 피처
# fee1H                   0.137065
# total_parking_spaces    0.106873
# bus_r300                0.084697
# cctv_r300               0.056166
# end_time                0.023483
# Name: class_1016, dtype: float64
#
# ▶ class_1017 기여도 상위 5개 피처
# bus_r300                  0.103580
# total_parking_spaces      0.078189
# end_time                  0.067004
# Weekday_operatingHours    0.041660
# start_time                0.015641
# Name: class_1017, dtype: float64
#
# ▶ class_1018 기여도 상위 5개 피처
# fee1H                     0.113994
# end_time                  0.112173
# Weekday_operatingHours    0.057974
# total_parking_spaces      0.021557
# operation_type            0.015572
# Name: class_1018, dtype: float64
#
# ▶ class_1019 기여도 상위 5개 피처
# cctv_r300               0.101479
# bus_r300                0.071383
# fee1H                   0.060432
# total_parking_spaces    0.056247
# end_time                0.048952
# Name: class_1019, dtype: float64
#
# ▶ class_1020 기여도 상위 5개 피처
# total_parking_spaces      0.170207
# end_time                  0.045649
# fee1H                     0.042285
# cctv_r300                 0.041357
# Weekday_operatingHours    0.030115
# Name: class_1020, dtype: float64
#
# ▶ class_1021 기여도 상위 5개 피처
# cctv_r300               0.111610
# fee1H                   0.102506
# total_parking_spaces    0.068774
# bus_r300                0.064640
# end_time                0.034591
# Name: class_1021, dtype: float64
#
# ▶ class_1022 기여도 상위 5개 피처
# fee1H                   0.122371
# cctv_r300               0.103379
# total_parking_spaces    0.059087
# bus_r300                0.019870
# end_time                0.019065
# Name: class_1022, dtype: float64
#
# ▶ class_1023 기여도 상위 5개 피처
# fee1H                   0.079285
# cctv_r300               0.078105
# total_parking_spaces    0.065763
# operation_type          0.052297
# bus_r300                0.050809
# Name: class_1023, dtype: float64
#
# ▶ class_1024 기여도 상위 5개 피처
# cctv_r300                 0.166949
# Weekday_operatingHours    0.061403
# end_time                  0.056245
# start_time                0.052637
# bus_r300                  0.041357
# Name: class_1024, dtype: float64
#
# ▶ class_1025 기여도 상위 5개 피처
# fee1H                   0.165096
# bus_r300                0.104137
# total_parking_spaces    0.099753
# cctv_r300               0.087783
# end_time                0.024249
# Name: class_1025, dtype: float64
#
# ▶ class_1026 기여도 상위 5개 피처
# end_time                  0.073071
# cctv_r300                 0.061322
# Weekday_operatingHours    0.055958
# total_parking_spaces      0.051790
# fee1H                     0.039049
# Name: class_1026, dtype: float64
#
# ▶ class_1027 기여도 상위 5개 피처
# fee1H                     0.090256
# total_parking_spaces      0.069115
# end_time                  0.057066
# bus_r300                  0.055743
# Weekday_operatingHours    0.039899
# Name: class_1027, dtype: float64
#
# ▶ class_1028 기여도 상위 5개 피처
# cctv_r300                 0.091996
# end_time                  0.061626
# Weekday_operatingHours    0.058904
# start_time                0.052179
# fee1H                     0.043576
# Name: class_1028, dtype: float64
#
# ▶ class_1029 기여도 상위 5개 피처
# bus_r300                0.180282
# cctv_r300               0.139665
# total_parking_spaces    0.099341
# fee1H                   0.033478
# end_time                0.025154
# Name: class_1029, dtype: float64
#
# ▶ class_1030 기여도 상위 5개 피처
# fee1H                     0.139716
# end_time                  0.039930
# Weekday_operatingHours    0.034746
# cctv_r300                 0.031851
# bus_r300                  0.027230
# Name: class_1030, dtype: float64
#
# ▶ class_1031 기여도 상위 5개 피처
# end_time                  0.073752
# total_parking_spaces      0.069440
# fee1H                     0.047671
# Weekday_operatingHours    0.042437
# bus_r300                  0.040834
# Name: class_1031, dtype: float64
#
# ▶ class_1032 기여도 상위 5개 피처
# end_time                0.069323
# bus_r300                0.062747
# total_parking_spaces    0.062091
# start_time              0.053463
# fee1H                   0.037043
# Name: class_1032, dtype: float64
#
# ▶ class_1033 기여도 상위 5개 피처
# fee1H                   0.095557
# bus_r300                0.073566
# total_parking_spaces    0.053098
# cctv_r300               0.048099
# end_time                0.047225
# Name: class_1033, dtype: float64
#
# ▶ class_1034 기여도 상위 5개 피처
# end_time                0.075221
# total_parking_spaces    0.063091
# cctv_r300               0.061412
# bus_r300                0.057832
# fee1H                   0.054801
# Name: class_1034, dtype: float64
#
# ▶ class_1035 기여도 상위 5개 피처
# end_time                  0.109313
# Weekday_operatingHours    0.061846
# fee1H                     0.053390
# bus_r300                  0.041784
# start_time                0.033403
# Name: class_1035, dtype: float64
#
# ▶ class_1036 기여도 상위 5개 피처
# cctv_r300                 0.081440
# bus_r300                  0.065381
# end_time                  0.064490
# fee1H                     0.048167
# Weekday_operatingHours    0.047383
# Name: class_1036, dtype: float64
#
# ▶ class_1037 기여도 상위 5개 피처
# end_time                  0.066992
# total_parking_spaces      0.056881
# cctv_r300                 0.056358
# Weekday_operatingHours    0.049657
# fee1H                     0.034779
# Name: class_1037, dtype: float64
#
# ▶ class_1038 기여도 상위 5개 피처
# cctv_r300               0.129187
# bus_r300                0.097077
# total_parking_spaces    0.079384
# fee1H                   0.035598
# end_time                0.027781
# Name: class_1038, dtype: float64
#
# ▶ class_1039 기여도 상위 5개 피처
# total_parking_spaces    0.247530
# fee1H                   0.074624
# bus_r300                0.057382
# cctv_r300               0.042159
# end_time                0.026237
# Name: class_1039, dtype: float64
#
# ▶ class_1040 기여도 상위 5개 피처
# bus_r300                0.143721
# cctv_r300               0.111181
# total_parking_spaces    0.074029
# fee1H                   0.053320
# end_time                0.021196
# Name: class_1040, dtype: float64
#
# ▶ class_1041 기여도 상위 5개 피처
# fee1H                     0.052718
# end_time                  0.052399
# bus_r300                  0.048027
# Weekday_operatingHours    0.033291
# cctv_r300                 0.032409
# Name: class_1041, dtype: float64
#
# ▶ class_1042 기여도 상위 5개 피처
# end_time                  0.091675
# bus_r300                  0.072750
# Weekday_operatingHours    0.054396
# fee1H                     0.050530
# total_parking_spaces      0.027845
# Name: class_1042, dtype: float64
#
# ▶ class_1043 기여도 상위 5개 피처
# cctv_r300               0.064665
# total_parking_spaces    0.058041
# end_time                0.045936
# bus_r300                0.041669
# fee1H                   0.039272
# Name: class_1043, dtype: float64
#
# ▶ class_1044 기여도 상위 5개 피처
# total_parking_spaces      0.079016
# fee1H                     0.071933
# end_time                  0.060287
# Weekday_operatingHours    0.058281
# start_time                0.024679
# Name: class_1044, dtype: float64
#
# ▶ class_1045 기여도 상위 5개 피처
# cctv_r300                 0.110653
# bus_r300                  0.074069
# end_time                  0.055247
# total_parking_spaces      0.048208
# Weekday_operatingHours    0.035368
# Name: class_1045, dtype: float64
#
# ▶ class_1046 기여도 상위 5개 피처
# total_parking_spaces      0.108711
# Weekday_operatingHours    0.064664
# start_time                0.063746
# end_time                  0.050112
# fee1H                     0.029911
# Name: class_1046, dtype: float64
#
# ▶ class_1047 기여도 상위 5개 피처
# end_time                  0.131449
# fee1H                     0.094362
# Weekday_operatingHours    0.066728
# operation_type            0.028253
# bus_r300                  0.025233
# Name: class_1047, dtype: float64
#
# ▶ class_1048 기여도 상위 5개 피처
# cctv_r300                 0.074990
# bus_r300                  0.060870
# end_time                  0.058757
# total_parking_spaces      0.051225
# Weekday_operatingHours    0.044027
# Name: class_1048, dtype: float64
#
# ▶ class_1049 기여도 상위 5개 피처
# end_time                  0.071755
# fee1H                     0.066896
# Weekday_operatingHours    0.043076
# bus_r300                  0.042840
# cctv_r300                 0.041480
# Name: class_1049, dtype: float64
#
# ▶ class_1050 기여도 상위 5개 피처
# total_parking_spaces    0.090329
# cctv_r300               0.078959
# bus_r300                0.053987
# end_time                0.050581
# operation_type          0.033486
# Name: class_1050, dtype: float64
#
# ▶ class_1051 기여도 상위 5개 피처
# end_time                  0.115548
# fee1H                     0.079278
# Weekday_operatingHours    0.060254
# cctv_r300                 0.060220
# bus_r300                  0.034693
# Name: class_1051, dtype: float64
#
# ▶ class_1052 기여도 상위 5개 피처
# fee1H                     0.090976
# end_time                  0.043131
# Weekday_operatingHours    0.042361
# bus_r300                  0.042336
# start_time                0.034938
# Name: class_1052, dtype: float64
#
# ▶ class_1053 기여도 상위 5개 피처
# cctv_r300               0.106307
# fee1H                   0.078461
# bus_r300                0.072646
# total_parking_spaces    0.064771
# end_time                0.029065
# Name: class_1053, dtype: float64
#
# ▶ class_1054 기여도 상위 5개 피처
# cctv_r300                 0.079276
# end_time                  0.062962
# start_time                0.051369
# Weekday_operatingHours    0.045449
# bus_r300                  0.042357
# Name: class_1054, dtype: float64
#
# ▶ class_1055 기여도 상위 5개 피처
# end_time                  0.069554
# cctv_r300                 0.055702
# bus_r300                  0.041744
# Weekday_operatingHours    0.041151
# fee1H                     0.034108
# Name: class_1055, dtype: float64
#
# ▶ class_1056 기여도 상위 5개 피처
# fee1H                   0.102806
# total_parking_spaces    0.090052
# cctv_r300               0.081847
# bus_r300                0.045986
# end_time                0.030830
# Name: class_1056, dtype: float64
#
# ▶ class_1057 기여도 상위 5개 피처
# fee1H                     0.090243
# total_parking_spaces      0.049847
# end_time                  0.042392
# Weekday_operatingHours    0.040299
# bus_r300                  0.027662
# Name: class_1057, dtype: float64
#
# ▶ class_1058 기여도 상위 5개 피처
# Weekday_operatingHours    0.085543
# start_time                0.059018
# cctv_r300                 0.054595
# fee1H                     0.039269
# end_time                  0.035601
# Name: class_1058, dtype: float64
#
# ▶ class_1059 기여도 상위 5개 피처
# total_parking_spaces      0.158287
# Weekday_operatingHours    0.073595
# cctv_r300                 0.048777
# start_time                0.041957
# fee1H                     0.039796
# Name: class_1059, dtype: float64
#
# ▶ class_1060 기여도 상위 5개 피처
# bus_r300                  0.097275
# Weekday_operatingHours    0.070251
# end_time                  0.061491
# start_time                0.056338
# fee1H                     0.030516
# Name: class_1060, dtype: float64
#
# ▶ class_1061 기여도 상위 5개 피처
# end_time                  0.059687
# bus_r300                  0.058461
# Weekday_operatingHours    0.046010
# start_time                0.043342
# total_parking_spaces      0.026359
# Name: class_1061, dtype: float64
#
# ▶ class_1062 기여도 상위 5개 피처
# end_time                  0.122155
# fee1H                     0.104922
# Weekday_operatingHours    0.064658
# bus_r300                  0.030927
# operation_type            0.028839
# Name: class_1062, dtype: float64
#
# ▶ class_1063 기여도 상위 5개 피처
# fee1H                     0.081262
# total_parking_spaces      0.055617
# end_time                  0.052853
# cctv_r300                 0.042237
# Weekday_operatingHours    0.037104
# Name: class_1063, dtype: float64
#
# ▶ class_1064 기여도 상위 5개 피처
# total_parking_spaces      0.111393
# fee1H                     0.104289
# end_time                  0.048666
# bus_r300                  0.042331
# Weekday_operatingHours    0.029482
# Name: class_1064, dtype: float64
#
# ▶ class_1065 기여도 상위 5개 피처
# end_time                  0.127537
# fee1H                     0.083003
# Weekday_operatingHours    0.066531
# cctv_r300                 0.050520
# total_parking_spaces      0.027093
# Name: class_1065, dtype: float64
#
# ▶ class_1066 기여도 상위 5개 피처
# total_parking_spaces      0.117474
# end_time                  0.064607
# cctv_r300                 0.063287
# bus_r300                  0.062011
# Weekday_operatingHours    0.047866
# Name: class_1066, dtype: float64
#
# ▶ class_1067 기여도 상위 5개 피처
# end_time                  0.068956
# fee1H                     0.064560
# cctv_r300                 0.060379
# Weekday_operatingHours    0.053988
# start_time                0.044883
# Name: class_1067, dtype: float64
#
# ▶ class_1068 기여도 상위 5개 피처
# bus_r300                  0.084161
# end_time                  0.064678
# cctv_r300                 0.051551
# Weekday_operatingHours    0.036165
# total_parking_spaces      0.029718
# Name: class_1068, dtype: float64
#
# ▶ class_1069 기여도 상위 5개 피처
# total_parking_spaces    0.111692
# bus_r300                0.101711
# fee1H                   0.069970
# cctv_r300               0.064420
# end_time                0.037011
# Name: class_1069, dtype: float64
#
# ▶ class_1070 기여도 상위 5개 피처
# end_time                  0.141469
# Weekday_operatingHours    0.078103
# cctv_r300                 0.073632
# operation_type            0.022522
# bus_r300                  0.020890
# Name: class_1070, dtype: float64

# %%
'''
# gradient boosting
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(random_state=0)
gb.fit(X_train, y_train)
pred = gb.predict(X_test)
accuracy = accuracy_score(y_test, pred)
print('gradient boosting 정확도: {:.4f}'.format(accuracy))
'''

# %%
from sklearn.metrics import mean_squared_error
import pandas as pd
pd.set_option('display.max_rows', None)

# 여기 요일타입에 따라 바꿔야 됩니다!!
dong_parks_df = pd.read_csv("src/dongParks_Weekday.csv")
dong_parks_df

# dong_parks_df의 feature 컬럼만 추출 (dong 이름 등 식별자 제외)
# 모델이 학습할 때 사용한 feature 리스트
model_features = list(rf.feature_names_in_)

# dong_parks_df에서 해당 컬럼만 추출
X_dong = dong_parks_df[model_features]
# 동별 민원 수준 예측
dong_parks_df['predicted_complaints'] = rf.predict(X_dong)

# 그룹별 동 이름 추출
high_dong = dong_parks_df[dong_parks_df['predicted_complaints'] == 2]['dong']
mid_dong = dong_parks_df[dong_parks_df['predicted_complaints'] == 1]['dong']
low_dong = dong_parks_df[dong_parks_df['predicted_complaints'] == 0]['dong']

# 각 그룹을 DataFrame으로 변환 (인덱스 리셋)
high_df = pd.DataFrame({'High 민원': high_dong.reset_index(drop=True)})
mid_df = pd.DataFrame({'Mid 민원': mid_dong.reset_index(drop=True)})
low_df = pd.DataFrame({'Low 민원': low_dong.reset_index(drop=True)})

# 길이가 다른 경우도 맞춰서 하나의 표로 합치기
dong_table = pd.concat([high_df, mid_df, low_df], axis=1)

from IPython.display import display
display(dong_table.head())
# Out:
#   High 민원 Mid 민원 Low 민원
# 0    가락본동   가리봉동    가산동
# 1    고덕2동    강일동   가양1동
# 2    구로2동   개포3동   가양2동
# 3    구로3동   거여2동   가양3동
# 4    구로4동    구산동   갈현1동

# %%
import pandas as pd

pd.Series(rf.feature_importances_, index=X_dong.columns).sort_values(ascending=False)
# Out:
# total_parking_spaces      0.225239
# bus_r300                  0.196104
# fee1H                     0.175595
# cctv_r300                 0.155748
# end_cos                   0.062120
# end_sin                   0.053904
# Weekday_operatingHours    0.052679
# operation_type            0.026863
# start_sin                 0.026162
# start_cos                 0.025584
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler


scaler = RobustScaler()
X_scaled = pd.DataFrame(
    scaler.fit_transform(X_dong),
    columns=X_dong.columns
)

'''
# 정규화 수행
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X_dong), columns=X_dong.columns)
'''

# 정규화된 데이터 기준으로 영향력 큰 feature 추정
importances = rf.feature_importances_
dong_parks_df['top_feature'] = X_scaled.apply(
    lambda row: row.index[np.argmax(np.abs(row.values * importances))],
    axis=1
)

# 결과 출력
solution_table = dong_parks_df[['dong', 'predicted_complaints', 'top_feature']]
display(solution_table.head())

# 민원 수준별 요약
summary = solution_table.groupby('predicted_complaints')['top_feature'].value_counts()
print(summary)
# Out:
#    dong  predicted_complaints           top_feature
# 0  가락본동                     2             cctv_r300
# 1  가리봉동                     1  total_parking_spaces
# 2   가산동                     0              bus_r300
# 3  가양1동                     0  total_parking_spaces
# 4  가양2동                     0              bus_r300
# predicted_complaints  top_feature
# 0                     fee1H                   56
#                       bus_r300                52
#                       total_parking_spaces    52
#                       cctv_r300               25
# 1                     fee1H                   29
#                       cctv_r300               18
#                       bus_r300                15
#                       total_parking_spaces    12
# 2                     cctv_r300               24
#                       total_parking_spaces    15
#                       bus_r300                12
#                       fee1H                   11
# Name: count, dtype: int64

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# 1) 행정동 경계 불러오기 (EPSG:5179)
dong_boundaries = (
    gpd.read_file("src/dong_boundary.shp")
       .rename(columns={"ADM_NM":"dong"})
)

# 3) 주소에서 ‘○○동’ 부분만 추출해 두기
parks_df['addr_dong'] = parks_df['address'].str.extract(r'^\S+\s+(\S+동)')[0]

# 4) GeoDataFrame 생성 (위경도 → EPSG:4326 지정)
geometry = [Point(xy) for xy in zip(parks_df['lon'], parks_df['lat'])]
parks_gdf = gpd.GeoDataFrame(
    parks_df,
    geometry=geometry,
    crs="EPSG:4326"
)

# 5) 경계 CRS로 투영
parks_gdf = parks_gdf.to_crs(dong_boundaries.crs)

# ─────── 이 부분을 추가 ───────
# 6) 공간 결합
parks_gdf = gpd.sjoin(
    parks_gdf,
    dong_boundaries[['dong','geometry']],
    how='left',
    predicate='within'
)

# 7) NaN인 경우만 매핑 테이블로 보정
mapping = {
    '잠실동': '잠실본동',
    # 필요시 다른 주소-행정동도 여기에 추가
}
parks_gdf['dong'] = parks_gdf['dong'].fillna(
    parks_gdf['addr_dong'].map(mapping)
)
# ─────────────────────────────

# 8) 결과 확인
parks_gdf = parks_gdf.drop(columns=['addr_dong', 'geometry', 'index_right'])
print(parks_gdf.columns)
# Out:
# Index(['address', 'parking_type', 'operation_type', 'total_parking_spaces',
#        'base_parking_fee', 'base_parking_time', 'additional_unit_fee',
#        'additional_unit_time', 'fee1H', 'cctv_r300', 'bus_r300',
#        'complaints_r300', 'Weekday_paid', 'Weekday_operatingHours', 'lon',
#        'lat', 'zoning_encoded', 'start_sin', 'start_cos', 'end_sin', 'end_cos',
#        'complaint_level', 'dong'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import shap

# 1) TreeExplainer 생성
explainer = shap.TreeExplainer(rf)
feature_cols = list(rf.feature_names_in_)

# 2) park-level SHAP 값 계산 (n_samples, n_features, n_classes)
raw_shap_p = explainer.shap_values(parks_gdf[feature_cols])

# 3) 클래스 차원 절댓값 평균 → (n_samples, n_features)
shap_abs_p = np.abs(raw_shap_p).mean(axis=2)

# 4) DataFrame으로 변환 후 dong 매핑
df_shap_p        = pd.DataFrame(shap_abs_p, columns=feature_cols)
df_shap_p['dong'] = parks_gdf['dong'].values

# 5) 행정동별 평균 SHAP 기여도 집계
dong_shap_mean = df_shap_p.groupby('dong').mean()

# 6) 행정동별 Top3 피처 추출
top3 = dong_shap_mean.apply(lambda row: row.nlargest(3).index.tolist(), axis=1)
df_top3 = (
    pd.DataFrame(top3.tolist(), index=top3.index, columns=['Top1','Top2','Top3'])
      .reset_index()
      .rename(columns={'index':'dong'})
)

# 7) 결과 확인
print(df_top3.head())
# Out:
#    dong                    Top1                  Top2                  Top3
# 0  가락본동                 end_cos                 fee1H               end_sin
# 1  가리봉동               cctv_r300  total_parking_spaces                 fee1H
# 2   가산동  Weekday_operatingHours               end_cos                 fee1H
# 3  가양1동               cctv_r300                 fee1H  total_parking_spaces
# 4  가양2동    total_parking_spaces              bus_r300             cctv_r300

# %%
# 1) 실제 complaints_level: parks_gdf 에 이미 있다면 바로 사용
#    없다면, 원본 complaints_df 등에서 행정동별로 집계해서 merge

# 예: 원본 parks_df 에 'complaints_level' 컬럼이 있다고 가정
actual = parks_gdf.groupby('dong')['complaint_level'] \
                   .agg(lambda x: x.mode()[0]) \
                   .reset_index()

# 2) 예측 complaints_level
predicted = pd.DataFrame({
    'dong': parks_gdf['dong'],
    'predicted_level': rf.predict(parks_gdf[feature_cols])
}).groupby('dong')['predicted_level'] \
  .agg(lambda x: x.mode()[0]) \
  .reset_index()

# 3) df_top3 에 결합
df_insight = (
    df_top3
      .merge(actual,    on='dong', how='left')
      .merge(predicted, on='dong', how='left')
)

df_insight.head()
# Out:
#    dong                    Top1                  Top2                  Top3  \
# 0  가락본동                 end_cos                 fee1H               end_sin
# 1  가리봉동               cctv_r300  total_parking_spaces                 fee1H
# 2   가산동  Weekday_operatingHours               end_cos                 fee1H
# 3  가양1동               cctv_r300                 fee1H  total_parking_spaces
# 4  가양2동    total_parking_spaces              bus_r300             cctv_r300
#
#   complaint_level  predicted_level
# 0               2                2
# 1               1                1
# 2               0                0
# 3               0                0
# 4               0                0

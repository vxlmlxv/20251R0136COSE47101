# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
#자연발생 클러스터링(민원 단계 컬럼 생성)
from jenkspy import JenksNaturalBreaks

parks_df = pd.read_csv("src/RF_parksdf_week.csv")
#parks_df = pd.read_csv("src/RF_parksdf_sat.csv")
#parks_df = pd.read_csv("src/RF_parksdf_holi.csv")

# 1) IQR 계산
Q1 = parks_df["complaints_r300"].quantile(0.25)
Q3 = parks_df["complaints_r300"].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# 2) 이상치 제거
outliers = parks_df[
    (parks_df["complaints_r300"] < lower_bound) |
    (parks_df["complaints_r300"] > upper_bound)
].copy()

parks_df = parks_df.drop(outliers.index).copy()

# 3) 필터된 데이터로 Jenks 적용
i = 3
breaks = JenksNaturalBreaks(n_classes=i)
breaks.fit(parks_df["complaints_r300"])
print("경계값:", breaks.breaks_)

# 4) 레이블 부여
parks_df["complaint_level"] = pd.cut(
    parks_df["complaints_r300"],
    bins=breaks.breaks_,
    labels=range(i),
    include_lowest=True
)
parks_df["complaint_level"].value_counts()
# Out:
# 경계값: [0, 913, 2107, 4099]
# complaint_level
# 0    800
# 1    459
# 2    273
# Name: count, dtype: int64

# %%
print(parks_df.columns)
# Out:
# Index(['address', 'parking_type', 'operation_type', 'total_parking_spaces',
#        'base_parking_fee', 'base_parking_time', 'additional_unit_fee',
#        'additional_unit_time', 'fee1H', 'cctv_r300', 'bus_r300',
#        'complaints_r300', 'Weekday_paid', 'Weekday_operatingHours', 'lon',
#        'lat', 'zoning_encoded', 'start_sin', 'start_cos', 'end_sin', 'end_cos',
#        'complaint_level'],
#       dtype='object')

# %%
#범주형 변수의 label을 [0,1]로 변환
from sklearn.preprocessing import LabelEncoder

le_dict = {}

for col in ["parking_type", "operation_type", "Weekday_paid", "Saturday_paid", "Holiday_paid"]:
    if col in parks_df.columns:  # ✅ 존재하는 경우에만 처리
        le = LabelEncoder()
        parks_df[col] = le.fit_transform(parks_df[col])
        le_dict[col] = le

# 예시: parking_type의 범주와 정수 매핑 확인
for col in le_dict:
    print(f"{col}: {list(le_dict[col].classes_)}")

# [0, 1, 2, ...] 순서로 classes_에 저장됨
#['NS', 'NW'] -> [0,1]
#[1, 3] -> [0,1]
#['N', 'Y'] -> [0,1]
#['N', 'Y'] -> [0,1]
#['N', 'Y'] -> [0,1]
# Out:
# parking_type: ['NS', 'NW']
# operation_type: [1, 3]
# Weekday_paid: ['N', 'Y']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# 0) 데이터 준비axis=
X = parks_df.drop(["complaints_r300", "complaint_level", "address", "lat", "lon",
                   "base_parking_fee", "base_parking_time", "additional_unit_fee", "additional_unit_time", "zoning_encoded"], axis=1)
y = parks_df["complaint_level"]

# 1) 80%를 train+val, 20%를 test로 분리 (stratify 유지)
X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# 2) train_val(80%) 중 12.5%를 val로 → 전체 비율 10%, train은 70%
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val,
    test_size=0.125,    # 0.8 * 0.125 = 0.1
    stratify=y_train_val,
    random_state=42
)
# 3) 훈련셋에서만 RandomForest로 피처 중요도 계산
rf_fs = RandomForestClassifier(random_state=0)
rf_fs.fit(X_train, y_train)

importances = pd.Series(rf_fs.feature_importances_, index=X_train.columns)
top10 = importances.nlargest(10).index.tolist()
print("선택된 상위 10개 피처:", top10)

if 'start_sin' in top10 and 'start_cos' not in top10:
    top10.append('start_cos')
if 'start_cos' in top10 and 'start_sin' not in top10:
    top10.append('start_sin')
# 이렇게 하면 둘이 반드시 함께 들어감


# 4) 선택된 피처로 데이터 재정의
X_train_sel = X_train[top10]
X_val_sel   = X_val[top10]
X_test_sel  = X_test[top10]

# 5) 최종 모델 학습 & 평가
rf = RandomForestClassifier(
    random_state=0,
    class_weight="balanced"   # 클래스 불균형 보정
)
rf.fit(X_train_sel, y_train)

val_pred  = rf.predict(X_val_sel)
test_pred = rf.predict(X_test_sel)

print("Validation 정확도: {:.4f}".format(accuracy_score(y_val, val_pred)))
print("Test 정확도      : {:.4f}".format(accuracy_score(y_test, test_pred)))
# Out:
# 선택된 상위 10개 피처: ['total_parking_spaces', 'bus_r300', 'cctv_r300', 'fee1H', 'Weekday_operatingHours', 'end_sin', 'end_cos', 'start_sin', 'start_cos', 'operation_type']
# Validation 정확도: 0.6234
# Test 정확도      : 0.7264

# %%
# Accuracy 분석

from sklearn.metrics import classification_report, accuracy_score

print("Complaint Level (Kmeans) Classification Accuracy:", round(accuracy_score(y_test, test_pred), 3))
print(classification_report(y_test, test_pred, target_names=['Low', 'Mid', 'High']))
# Out:
# Complaint Level (Kmeans) Classification Accuracy: 0.726
#               precision    recall  f1-score   support
#
#          Low       0.84      0.87      0.86       160
#          Mid       0.59      0.55      0.57        92
#         High       0.59      0.60      0.59        55
#
#     accuracy                           0.73       307
#    macro avg       0.67      0.67      0.67       307
# weighted avg       0.72      0.73      0.72       307

# %%
importances = rf.feature_importances_
feature_names = top10  # DataFrame에서 feature 이름 추출

# 중요도 표 만들기
importance_table = pd.DataFrame({
    'feature': feature_names,
    'importance': importances
}).sort_values(by='importance', ascending=False)

importance_table
# Out:
#                   feature  importance
# 0    total_parking_spaces    0.223380
# 1                bus_r300    0.197859
# 3                   fee1H    0.172679
# 2               cctv_r300    0.160017
# 6                 end_cos    0.061390
# 5                 end_sin    0.054610
# 4  Weekday_operatingHours    0.052322
# 9          operation_type    0.027090
# 7               start_sin    0.025401
# 8               start_cos    0.025253

# %%
import numpy as np
import pandas as pd
import shap

# ── 1) 기존 mean_abs_shap 계산 (axis=0 으로 피처별 평균 절댓값 SHAP) ─────
explainer = shap.TreeExplainer(rf)
shap_vals = explainer.shap_values(X_train_sel)

mean_abs_shap = pd.DataFrame({
    f'class_{cls}': np.abs(shap_vals[cls]).mean(axis=1)
    for cls in range(len(shap_vals))
}, index=top10)

# ── 2) start_time, end_time 그룹 중요도 (Euclidean norm) 계산 ──────────
for cls in mean_abs_shap.columns:
    # start_time
    s_sin = mean_abs_shap.loc['start_sin', cls]
    s_cos = mean_abs_shap.loc['start_cos', cls]
    mean_abs_shap.loc['start_time', cls] = np.sqrt(s_sin**2 + s_cos**2)
    # end_time
    e_sin = mean_abs_shap.loc['end_sin', cls]
    e_cos = mean_abs_shap.loc['end_cos', cls]
    mean_abs_shap.loc['end_time', cls] = np.sqrt(e_sin**2 + e_cos**2)

# ── 3) sin/cos 개별 행 제거하여 그룹화된 DataFrame 구성 ────────────────
grouped_shap = mean_abs_shap.drop(
    ['start_sin','start_cos','end_sin','end_cos'],
    axis=0
)

# ── 4) 클래스별 상위 N개 피처 출력 ──────────────────────────────────
top_n = 5
for cls in grouped_shap.columns:
    print(f"\n▶ {cls} 기여도 상위 {top_n}개 피처")
    print(grouped_shap[cls].sort_values(ascending=False).head(top_n))
# Out:
# ▶ class_0 기여도 상위 5개 피처
# end_time                  0.129419
# fee1H                     0.088352
# Weekday_operatingHours    0.064053
# cctv_r300                 0.037974
# bus_r300                  0.020568
# Name: class_0, dtype: float64
#
# ▶ class_1 기여도 상위 5개 피처
# cctv_r300               0.085809
# fee1H                   0.068770
# end_time                0.037580
# total_parking_spaces    0.029318
# bus_r300                0.027743
# Name: class_1, dtype: float64
#
# ▶ class_2 기여도 상위 5개 피처
# end_time                  0.109054
# operation_type            0.079705
# Weekday_operatingHours    0.061557
# bus_r300                  0.047206
# fee1H                     0.047133
# Name: class_2, dtype: float64
#
# ▶ class_3 기여도 상위 5개 피처
# cctv_r300                 0.079494
# bus_r300                  0.077874
# fee1H                     0.056207
# end_time                  0.054887
# Weekday_operatingHours    0.043098
# Name: class_3, dtype: float64
#
# ▶ class_4 기여도 상위 5개 피처
# cctv_r300                 0.086029
# bus_r300                  0.074690
# end_time                  0.061900
# fee1H                     0.047290
# Weekday_operatingHours    0.037636
# Name: class_4, dtype: float64
#
# ▶ class_5 기여도 상위 5개 피처
# bus_r300                0.079857
# cctv_r300               0.073239
# fee1H                   0.070725
# end_time                0.034429
# total_parking_spaces    0.032721
# Name: class_5, dtype: float64
#
# ▶ class_6 기여도 상위 5개 피처
# fee1H                   0.095323
# end_time                0.060760
# bus_r300                0.056614
# total_parking_spaces    0.048581
# cctv_r300               0.030707
# Name: class_6, dtype: float64
#
# ▶ class_7 기여도 상위 5개 피처
# end_time                  0.070779
# bus_r300                  0.065943
# Weekday_operatingHours    0.048657
# total_parking_spaces      0.041774
# start_time                0.031595
# Name: class_7, dtype: float64
#
# ▶ class_8 기여도 상위 5개 피처
# fee1H                   0.118717
# cctv_r300               0.071126
# end_time                0.047411
# bus_r300                0.036600
# total_parking_spaces    0.035884
# Name: class_8, dtype: float64
#
# ▶ class_9 기여도 상위 5개 피처
# end_time                  0.133101
# fee1H                     0.092035
# Weekday_operatingHours    0.064074
# total_parking_spaces      0.022937
# bus_r300                  0.022527
# Name: class_9, dtype: float64
#
# ▶ class_10 기여도 상위 5개 피처
# total_parking_spaces      0.065262
# Weekday_operatingHours    0.065008
# end_time                  0.064326
# start_time                0.062145
# bus_r300                  0.031358
# Name: class_10, dtype: float64
#
# ▶ class_11 기여도 상위 5개 피처
# cctv_r300               0.112012
# bus_r300                0.077970
# fee1H                   0.056270
# end_time                0.053603
# total_parking_spaces    0.031097
# Name: class_11, dtype: float64
#
# ▶ class_12 기여도 상위 5개 피처
# end_time                  0.125644
# total_parking_spaces      0.055052
# fee1H                     0.048497
# cctv_r300                 0.036711
# Weekday_operatingHours    0.035874
# Name: class_12, dtype: float64
#
# ▶ class_13 기여도 상위 5개 피처
# total_parking_spaces      0.116173
# bus_r300                  0.079851
# end_time                  0.065634
# cctv_r300                 0.064955
# Weekday_operatingHours    0.043027
# Name: class_13, dtype: float64
#
# ▶ class_14 기여도 상위 5개 피처
# cctv_r300               0.107206
# total_parking_spaces    0.098059
# fee1H                   0.042646
# bus_r300                0.042441
# end_time                0.036851
# Name: class_14, dtype: float64
#
# ▶ class_15 기여도 상위 5개 피처
# fee1H                     0.080767
# cctv_r300                 0.080468
# end_time                  0.050824
# total_parking_spaces      0.044252
# Weekday_operatingHours    0.041151
# Name: class_15, dtype: float64
#
# ▶ class_16 기여도 상위 5개 피처
# fee1H                   0.171034
# cctv_r300               0.056640
# total_parking_spaces    0.024102
# end_time                0.021909
# operation_type          0.015410
# Name: class_16, dtype: float64
#
# ▶ class_17 기여도 상위 5개 피처
# total_parking_spaces      0.105725
# fee1H                     0.095034
# cctv_r300                 0.060401
# end_time                  0.055102
# Weekday_operatingHours    0.033269
# Name: class_17, dtype: float64
#
# ▶ class_18 기여도 상위 5개 피처
# end_time                  0.094070
# cctv_r300                 0.087471
# fee1H                     0.082238
# bus_r300                  0.056751
# Weekday_operatingHours    0.048844
# Name: class_18, dtype: float64
#
# ▶ class_19 기여도 상위 5개 피처
# end_time                  0.139719
# fee1H                     0.105331
# Weekday_operatingHours    0.071126
# bus_r300                  0.030206
# total_parking_spaces      0.021913
# Name: class_19, dtype: float64
#
# ▶ class_20 기여도 상위 5개 피처
# fee1H                   0.119431
# total_parking_spaces    0.117251
# bus_r300                0.062312
# end_time                0.038405
# cctv_r300               0.035037
# Name: class_20, dtype: float64
#
# ▶ class_21 기여도 상위 5개 피처
# cctv_r300               0.139528
# total_parking_spaces    0.103635
# fee1H                   0.101245
# bus_r300                0.040370
# end_time                0.031888
# Name: class_21, dtype: float64
#
# ▶ class_22 기여도 상위 5개 피처
# Weekday_operatingHours    0.103196
# end_time                  0.079052
# start_time                0.061198
# fee1H                     0.049510
# total_parking_spaces      0.040022
# Name: class_22, dtype: float64
#
# ▶ class_23 기여도 상위 5개 피처
# total_parking_spaces    0.069735
# cctv_r300               0.062217
# bus_r300                0.058280
# end_time                0.048231
# fee1H                   0.046800
# Name: class_23, dtype: float64
#
# ▶ class_24 기여도 상위 5개 피처
# total_parking_spaces      0.138350
# end_time                  0.068413
# cctv_r300                 0.053959
# bus_r300                  0.047607
# Weekday_operatingHours    0.039525
# Name: class_24, dtype: float64
#
# ▶ class_25 기여도 상위 5개 피처
# total_parking_spaces    0.164898
# fee1H                   0.061439
# end_time                0.043812
# bus_r300                0.040045
# start_time              0.034013
# Name: class_25, dtype: float64
#
# ▶ class_26 기여도 상위 5개 피처
# bus_r300                  0.092596
# total_parking_spaces      0.070244
# end_time                  0.044875
# fee1H                     0.043369
# Weekday_operatingHours    0.034504
# Name: class_26, dtype: float64
#
# ▶ class_27 기여도 상위 5개 피처
# total_parking_spaces      0.176348
# bus_r300                  0.101724
# fee1H                     0.052031
# cctv_r300                 0.029740
# Weekday_operatingHours    0.019781
# Name: class_27, dtype: float64
#
# ▶ class_28 기여도 상위 5개 피처
# total_parking_spaces      0.068437
# end_time                  0.064325
# Weekday_operatingHours    0.041911
# bus_r300                  0.031378
# cctv_r300                 0.027985
# Name: class_28, dtype: float64
#
# ▶ class_29 기여도 상위 5개 피처
# cctv_r300                 0.076588
# end_time                  0.057627
# bus_r300                  0.049843
# total_parking_spaces      0.039916
# Weekday_operatingHours    0.036599
# Name: class_29, dtype: float64
#
# ▶ class_30 기여도 상위 5개 피처
# bus_r300                0.065310
# total_parking_spaces    0.057442
# fee1H                   0.054890
# operation_type          0.050645
# cctv_r300               0.038380
# Name: class_30, dtype: float64
#
# ▶ class_31 기여도 상위 5개 피처
# cctv_r300                 0.102102
# end_time                  0.069683
# total_parking_spaces      0.057292
# Weekday_operatingHours    0.041201
# bus_r300                  0.039402
# Name: class_31, dtype: float64
#
# ▶ class_32 기여도 상위 5개 피처
# end_time                  0.068592
# bus_r300                  0.057810
# total_parking_spaces      0.043091
# Weekday_operatingHours    0.042312
# cctv_r300                 0.037517
# Name: class_32, dtype: float64
#
# ▶ class_33 기여도 상위 5개 피처
# fee1H                   0.081416
# total_parking_spaces    0.063341
# cctv_r300               0.063058
# end_time                0.051949
# bus_r300                0.028827
# Name: class_33, dtype: float64
#
# ▶ class_34 기여도 상위 5개 피처
# total_parking_spaces      0.106797
# Weekday_operatingHours    0.086176
# end_time                  0.070574
# cctv_r300                 0.052722
# fee1H                     0.034418
# Name: class_34, dtype: float64
#
# ▶ class_35 기여도 상위 5개 피처
# fee1H                   0.090746
# cctv_r300               0.084086
# total_parking_spaces    0.060257
# end_time                0.048682
# bus_r300                0.037304
# Name: class_35, dtype: float64
#
# ▶ class_36 기여도 상위 5개 피처
# fee1H                   0.138993
# cctv_r300               0.121379
# total_parking_spaces    0.019169
# end_time                0.018839
# bus_r300                0.016035
# Name: class_36, dtype: float64
#
# ▶ class_37 기여도 상위 5개 피처
# end_time                  0.062543
# bus_r300                  0.062189
# cctv_r300                 0.053367
# fee1H                     0.045940
# Weekday_operatingHours    0.044356
# Name: class_37, dtype: float64
#
# ▶ class_38 기여도 상위 5개 피처
# end_time                  0.123956
# fee1H                     0.102622
# Weekday_operatingHours    0.065432
# operation_type            0.027907
# total_parking_spaces      0.023829
# Name: class_38, dtype: float64
#
# ▶ class_39 기여도 상위 5개 피처
# bus_r300                  0.105234
# fee1H                     0.102105
# Weekday_operatingHours    0.068896
# total_parking_spaces      0.056273
# end_time                  0.045614
# Name: class_39, dtype: float64
#
# ▶ class_40 기여도 상위 5개 피처
# end_time                  0.064434
# Weekday_operatingHours    0.041767
# total_parking_spaces      0.040781
# start_time                0.031481
# cctv_r300                 0.018597
# Name: class_40, dtype: float64
#
# ▶ class_41 기여도 상위 5개 피처
# cctv_r300                 0.075195
# end_time                  0.056470
# start_time                0.052182
# Weekday_operatingHours    0.048796
# bus_r300                  0.045328
# Name: class_41, dtype: float64
#
# ▶ class_42 기여도 상위 5개 피처
# fee1H                     0.068398
# end_time                  0.063356
# total_parking_spaces      0.040787
# cctv_r300                 0.039992
# Weekday_operatingHours    0.038272
# Name: class_42, dtype: float64
#
# ▶ class_43 기여도 상위 5개 피처
# cctv_r300               0.107128
# fee1H                   0.063532
# end_time                0.062778
# total_parking_spaces    0.061688
# bus_r300                0.059210
# Name: class_43, dtype: float64
#
# ▶ class_44 기여도 상위 5개 피처
# end_time                  0.120786
# total_parking_spaces      0.086938
# Weekday_operatingHours    0.077195
# fee1H                     0.046581
# bus_r300                  0.024637
# Name: class_44, dtype: float64
#
# ▶ class_45 기여도 상위 5개 피처
# bus_r300                  0.095753
# fee1H                     0.068275
# end_time                  0.057038
# total_parking_spaces      0.041938
# Weekday_operatingHours    0.036920
# Name: class_45, dtype: float64
#
# ▶ class_46 기여도 상위 5개 피처
# end_time                  0.115394
# fee1H                     0.111430
# Weekday_operatingHours    0.057854
# total_parking_spaces      0.029288
# bus_r300                  0.017499
# Name: class_46, dtype: float64
#
# ▶ class_47 기여도 상위 5개 피처
# cctv_r300                 0.138637
# bus_r300                  0.133566
# end_time                  0.044489
# Weekday_operatingHours    0.032750
# total_parking_spaces      0.030071
# Name: class_47, dtype: float64
#
# ▶ class_48 기여도 상위 5개 피처
# end_time                  0.126338
# total_parking_spaces      0.084551
# fee1H                     0.079921
# Weekday_operatingHours    0.065150
# operation_type            0.015618
# Name: class_48, dtype: float64
#
# ▶ class_49 기여도 상위 5개 피처
# cctv_r300               0.122036
# total_parking_spaces    0.072568
# operation_type          0.069364
# end_time                0.069067
# fee1H                   0.053127
# Name: class_49, dtype: float64
#
# ▶ class_50 기여도 상위 5개 피처
# cctv_r300                 0.071655
# end_time                  0.049515
# total_parking_spaces      0.048723
# bus_r300                  0.037028
# Weekday_operatingHours    0.035654
# Name: class_50, dtype: float64
#
# ▶ class_51 기여도 상위 5개 피처
# fee1H                     0.120846
# end_time                  0.045133
# Weekday_operatingHours    0.037345
# total_parking_spaces      0.035264
# start_time                0.025296
# Name: class_51, dtype: float64
#
# ▶ class_52 기여도 상위 5개 피처
# fee1H                     0.070565
# end_time                  0.059119
# bus_r300                  0.051382
# total_parking_spaces      0.036076
# Weekday_operatingHours    0.032599
# Name: class_52, dtype: float64
#
# ▶ class_53 기여도 상위 5개 피처
# end_time                  0.127087
# fee1H                     0.065955
# Weekday_operatingHours    0.063287
# cctv_r300                 0.050494
# bus_r300                  0.037859
# Name: class_53, dtype: float64
#
# ▶ class_54 기여도 상위 5개 피처
# fee1H                     0.075166
# end_time                  0.068139
# total_parking_spaces      0.067749
# cctv_r300                 0.048194
# Weekday_operatingHours    0.046052
# Name: class_54, dtype: float64
#
# ▶ class_55 기여도 상위 5개 피처
# total_parking_spaces    0.120188
# end_time                0.062480
# fee1H                   0.055103
# bus_r300                0.052967
# start_time              0.039996
# Name: class_55, dtype: float64
#
# ▶ class_56 기여도 상위 5개 피처
# bus_r300                  0.110711
# Weekday_operatingHours    0.067878
# start_time                0.067100
# end_time                  0.062971
# fee1H                     0.033372
# Name: class_56, dtype: float64
#
# ▶ class_57 기여도 상위 5개 피처
# end_time                  0.136322
# Weekday_operatingHours    0.067286
# fee1H                     0.067045
# cctv_r300                 0.048264
# bus_r300                  0.021304
# Name: class_57, dtype: float64
#
# ▶ class_58 기여도 상위 5개 피처
# end_time                  0.060552
# cctv_r300                 0.053888
# total_parking_spaces      0.052003
# Weekday_operatingHours    0.044349
# fee1H                     0.037059
# Name: class_58, dtype: float64
#
# ▶ class_59 기여도 상위 5개 피처
# fee1H                   0.090632
# total_parking_spaces    0.084256
# bus_r300                0.068341
# cctv_r300               0.058651
# end_time                0.044930
# Name: class_59, dtype: float64
#
# ▶ class_60 기여도 상위 5개 피처
# cctv_r300                 0.136590
# Weekday_operatingHours    0.067306
# start_time                0.062440
# end_time                  0.059601
# fee1H                     0.022398
# Name: class_60, dtype: float64
#
# ▶ class_61 기여도 상위 5개 피처
# cctv_r300                 0.100841
# total_parking_spaces      0.059282
# bus_r300                  0.056084
# end_time                  0.040664
# Weekday_operatingHours    0.016674
# Name: class_61, dtype: float64
#
# ▶ class_62 기여도 상위 5개 피처
# cctv_r300               0.138105
# fee1H                   0.092404
# total_parking_spaces    0.075197
# end_time                0.018616
# operation_type          0.011488
# Name: class_62, dtype: float64
#
# ▶ class_63 기여도 상위 5개 피처
# bus_r300                0.163265
# cctv_r300               0.137807
# total_parking_spaces    0.080107
# fee1H                   0.076664
# end_time                0.026197
# Name: class_63, dtype: float64
#
# ▶ class_64 기여도 상위 5개 피처
# bus_r300                0.139327
# total_parking_spaces    0.102549
# cctv_r300               0.082817
# end_time                0.034372
# operation_type          0.023959
# Name: class_64, dtype: float64
#
# ▶ class_65 기여도 상위 5개 피처
# total_parking_spaces    0.089861
# fee1H                   0.074999
# end_time                0.042353
# cctv_r300               0.041462
# start_time              0.040735
# Name: class_65, dtype: float64
#
# ▶ class_66 기여도 상위 5개 피처
# end_time                  0.074251
# Weekday_operatingHours    0.050173
# bus_r300                  0.046926
# cctv_r300                 0.046030
# total_parking_spaces      0.039493
# Name: class_66, dtype: float64
#
# ▶ class_67 기여도 상위 5개 피처
# total_parking_spaces    0.118271
# bus_r300                0.074268
# cctv_r300               0.069596
# fee1H                   0.065227
# start_time              0.023154
# Name: class_67, dtype: float64
#
# ▶ class_68 기여도 상위 5개 피처
# fee1H                   0.126346
# cctv_r300               0.110642
# total_parking_spaces    0.022270
# end_time                0.021539
# operation_type          0.013512
# Name: class_68, dtype: float64
#
# ▶ class_69 기여도 상위 5개 피처
# fee1H                     0.090089
# end_time                  0.074724
# total_parking_spaces      0.050992
# bus_r300                  0.045985
# Weekday_operatingHours    0.040079
# Name: class_69, dtype: float64
#
# ▶ class_70 기여도 상위 5개 피처
# bus_r300                  0.073959
# cctv_r300                 0.060756
# end_time                  0.058638
# Weekday_operatingHours    0.038082
# fee1H                     0.036782
# Name: class_70, dtype: float64
#
# ▶ class_71 기여도 상위 5개 피처
# fee1H                   0.068358
# end_time                0.062928
# bus_r300                0.053941
# start_time              0.048946
# total_parking_spaces    0.047579
# Name: class_71, dtype: float64
#
# ▶ class_72 기여도 상위 5개 피처
# total_parking_spaces      0.088154
# end_time                  0.063318
# fee1H                     0.045966
# cctv_r300                 0.037646
# Weekday_operatingHours    0.024214
# Name: class_72, dtype: float64
#
# ▶ class_73 기여도 상위 5개 피처
# end_time                  0.131794
# fee1H                     0.099317
# Weekday_operatingHours    0.060863
# bus_r300                  0.023438
# total_parking_spaces      0.022108
# Name: class_73, dtype: float64
#
# ▶ class_74 기여도 상위 5개 피처
# fee1H                     0.111848
# bus_r300                  0.081246
# end_time                  0.080975
# cctv_r300                 0.034582
# Weekday_operatingHours    0.032454
# Name: class_74, dtype: float64
#
# ▶ class_75 기여도 상위 5개 피처
# end_time                  0.071681
# Weekday_operatingHours    0.069364
# bus_r300                  0.065089
# start_time                0.058075
# fee1H                     0.054900
# Name: class_75, dtype: float64
#
# ▶ class_76 기여도 상위 5개 피처
# fee1H                     0.131981
# end_time                  0.066294
# bus_r300                  0.051729
# total_parking_spaces      0.039051
# Weekday_operatingHours    0.038469
# Name: class_76, dtype: float64
#
# ▶ class_77 기여도 상위 5개 피처
# cctv_r300               0.142608
# fee1H                   0.134996
# bus_r300                0.096814
# total_parking_spaces    0.088454
# end_time                0.024864
# Name: class_77, dtype: float64
#
# ▶ class_78 기여도 상위 5개 피처
# fee1H                     0.123943
# end_time                  0.053239
# bus_r300                  0.033911
# total_parking_spaces      0.033201
# Weekday_operatingHours    0.028104
# Name: class_78, dtype: float64
#
# ▶ class_79 기여도 상위 5개 피처
# end_time                  0.145263
# fee1H                     0.091482
# Weekday_operatingHours    0.071906
# bus_r300                  0.018814
# start_time                0.016501
# Name: class_79, dtype: float64
#
# ▶ class_80 기여도 상위 5개 피처
# end_time                  0.130471
# fee1H                     0.072421
# Weekday_operatingHours    0.068191
# cctv_r300                 0.051695
# operation_type            0.020580
# Name: class_80, dtype: float64
#
# ▶ class_81 기여도 상위 5개 피처
# end_time                  0.071274
# total_parking_spaces      0.045501
# bus_r300                  0.034442
# start_time                0.030062
# Weekday_operatingHours    0.029737
# Name: class_81, dtype: float64
#
# ▶ class_82 기여도 상위 5개 피처
# cctv_r300                 0.177553
# start_time                0.063520
# Weekday_operatingHours    0.063048
# end_time                  0.050604
# fee1H                     0.017652
# Name: class_82, dtype: float64
#
# ▶ class_83 기여도 상위 5개 피처
# total_parking_spaces      0.124261
# end_time                  0.054979
# bus_r300                  0.043941
# fee1H                     0.040690
# Weekday_operatingHours    0.029024
# Name: class_83, dtype: float64
#
# ▶ class_84 기여도 상위 5개 피처
# fee1H                     0.092204
# end_time                  0.073645
# Weekday_operatingHours    0.067205
# start_time                0.050124
# total_parking_spaces      0.046013
# Name: class_84, dtype: float64
#
# ▶ class_85 기여도 상위 5개 피처
# end_time                  0.094340
# start_time                0.090987
# Weekday_operatingHours    0.083970
# cctv_r300                 0.044018
# fee1H                     0.038011
# Name: class_85, dtype: float64
#
# ▶ class_86 기여도 상위 5개 피처
# total_parking_spaces      0.086804
# bus_r300                  0.073767
# end_time                  0.057670
# cctv_r300                 0.057505
# Weekday_operatingHours    0.047837
# Name: class_86, dtype: float64
#
# ▶ class_87 기여도 상위 5개 피처
# fee1H                   0.109179
# end_time                0.058356
# cctv_r300               0.057973
# total_parking_spaces    0.045612
# bus_r300                0.040783
# Name: class_87, dtype: float64
#
# ▶ class_88 기여도 상위 5개 피처
# end_time                  0.094210
# Weekday_operatingHours    0.091196
# bus_r300                  0.068920
# start_time                0.051360
# cctv_r300                 0.031039
# Name: class_88, dtype: float64
#
# ▶ class_89 기여도 상위 5개 피처
# cctv_r300                 0.068414
# total_parking_spaces      0.067782
# end_time                  0.058969
# Weekday_operatingHours    0.037736
# fee1H                     0.031963
# Name: class_89, dtype: float64
#
# ▶ class_90 기여도 상위 5개 피처
# cctv_r300                 0.113195
# end_time                  0.065699
# total_parking_spaces      0.046890
# Weekday_operatingHours    0.037453
# bus_r300                  0.035063
# Name: class_90, dtype: float64
#
# ▶ class_91 기여도 상위 5개 피처
# end_time                  0.086668
# cctv_r300                 0.072462
# Weekday_operatingHours    0.054426
# total_parking_spaces      0.053819
# bus_r300                  0.045945
# Name: class_91, dtype: float64
#
# ▶ class_92 기여도 상위 5개 피처
# end_time                  0.077644
# cctv_r300                 0.067246
# total_parking_spaces      0.064860
# Weekday_operatingHours    0.037828
# bus_r300                  0.034452
# Name: class_92, dtype: float64
#
# ▶ class_93 기여도 상위 5개 피처
# cctv_r300                 0.084771
# fee1H                     0.082622
# end_time                  0.052284
# bus_r300                  0.048459
# Weekday_operatingHours    0.020203
# Name: class_93, dtype: float64
#
# ▶ class_94 기여도 상위 5개 피처
# end_time                  0.073982
# total_parking_spaces      0.047291
# Weekday_operatingHours    0.045343
# cctv_r300                 0.036734
# fee1H                     0.034667
# Name: class_94, dtype: float64
#
# ▶ class_95 기여도 상위 5개 피처
# end_time                  0.160801
# Weekday_operatingHours    0.090384
# bus_r300                  0.031450
# cctv_r300                 0.028272
# total_parking_spaces      0.024981
# Name: class_95, dtype: float64
#
# ▶ class_96 기여도 상위 5개 피처
# bus_r300                  0.175627
# fee1H                     0.086227
# total_parking_spaces      0.060092
# cctv_r300                 0.031498
# Weekday_operatingHours    0.019849
# Name: class_96, dtype: float64
#
# ▶ class_97 기여도 상위 5개 피처
# end_time                0.078659
# start_time              0.061562
# total_parking_spaces    0.053611
# bus_r300                0.048384
# fee1H                   0.038470
# Name: class_97, dtype: float64
#
# ▶ class_98 기여도 상위 5개 피처
# fee1H                     0.064108
# total_parking_spaces      0.063488
# bus_r300                  0.060521
# end_time                  0.056860
# Weekday_operatingHours    0.027791
# Name: class_98, dtype: float64
#
# ▶ class_99 기여도 상위 5개 피처
# end_time                  0.131151
# fee1H                     0.092390
# Weekday_operatingHours    0.062422
# bus_r300                  0.027066
# total_parking_spaces      0.025698
# Name: class_99, dtype: float64
#
# ▶ class_100 기여도 상위 5개 피처
# fee1H                   0.067568
# cctv_r300               0.059208
# end_time                0.048666
# total_parking_spaces    0.046174
# bus_r300                0.038389
# Name: class_100, dtype: float64
#
# ▶ class_101 기여도 상위 5개 피처
# fee1H                     0.092274
# end_time                  0.060335
# bus_r300                  0.039255
# Weekday_operatingHours    0.034500
# cctv_r300                 0.027442
# Name: class_101, dtype: float64
#
# ▶ class_102 기여도 상위 5개 피처
# bus_r300                0.073473
# total_parking_spaces    0.044369
# fee1H                   0.042996
# start_time              0.037989
# end_time                0.035719
# Name: class_102, dtype: float64
#
# ▶ class_103 기여도 상위 5개 피처
# end_time                  0.068869
# fee1H                     0.052546
# cctv_r300                 0.044281
# Weekday_operatingHours    0.040884
# bus_r300                  0.038701
# Name: class_103, dtype: float64
#
# ▶ class_104 기여도 상위 5개 피처
# end_time                  0.125491
# fee1H                     0.103528
# Weekday_operatingHours    0.067153
# operation_type            0.031485
# bus_r300                  0.025726
# Name: class_104, dtype: float64
#
# ▶ class_105 기여도 상위 5개 피처
# total_parking_spaces    0.103515
# bus_r300                0.100128
# start_time              0.044088
# end_time                0.041664
# fee1H                   0.039247
# Name: class_105, dtype: float64
#
# ▶ class_106 기여도 상위 5개 피처
# cctv_r300                 0.123400
# fee1H                     0.096512
# bus_r300                  0.075253
# total_parking_spaces      0.062863
# Weekday_operatingHours    0.024321
# Name: class_106, dtype: float64
#
# ▶ class_107 기여도 상위 5개 피처
# end_time                  0.062160
# total_parking_spaces      0.052353
# cctv_r300                 0.049538
# bus_r300                  0.044368
# Weekday_operatingHours    0.040127
# Name: class_107, dtype: float64
#
# ▶ class_108 기여도 상위 5개 피처
# fee1H                     0.077681
# end_time                  0.068686
# cctv_r300                 0.058328
# Weekday_operatingHours    0.034086
# bus_r300                  0.032541
# Name: class_108, dtype: float64
#
# ▶ class_109 기여도 상위 5개 피처
# cctv_r300                 0.122712
# fee1H                     0.108301
# total_parking_spaces      0.104248
# bus_r300                  0.065597
# Weekday_operatingHours    0.023463
# Name: class_109, dtype: float64
#
# ▶ class_110 기여도 상위 5개 피처
# cctv_r300               0.111486
# total_parking_spaces    0.097773
# end_time                0.074032
# fee1H                   0.062579
# start_time              0.049331
# Name: class_110, dtype: float64
#
# ▶ class_111 기여도 상위 5개 피처
# end_time                  0.143621
# fee1H                     0.065911
# start_time                0.040392
# Weekday_operatingHours    0.034176
# total_parking_spaces      0.029069
# Name: class_111, dtype: float64
#
# ▶ class_112 기여도 상위 5개 피처
# fee1H                   0.143465
# end_time                0.045058
# bus_r300                0.041780
# cctv_r300               0.037580
# total_parking_spaces    0.035609
# Name: class_112, dtype: float64
#
# ▶ class_113 기여도 상위 5개 피처
# fee1H                     0.102171
# end_time                  0.050282
# bus_r300                  0.046585
# total_parking_spaces      0.041914
# Weekday_operatingHours    0.037710
# Name: class_113, dtype: float64
#
# ▶ class_114 기여도 상위 5개 피처
# fee1H                   0.090652
# total_parking_spaces    0.084467
# bus_r300                0.073016
# cctv_r300               0.058979
# end_time                0.045103
# Name: class_114, dtype: float64
#
# ▶ class_115 기여도 상위 5개 피처
# bus_r300                  0.140144
# fee1H                     0.077983
# end_time                  0.064450
# total_parking_spaces      0.048673
# Weekday_operatingHours    0.042951
# Name: class_115, dtype: float64
#
# ▶ class_116 기여도 상위 5개 피처
# cctv_r300                 0.119023
# end_time                  0.070496
# total_parking_spaces      0.061992
# bus_r300                  0.043268
# Weekday_operatingHours    0.038617
# Name: class_116, dtype: float64
#
# ▶ class_117 기여도 상위 5개 피처
# total_parking_spaces    0.289211
# bus_r300                0.061134
# cctv_r300               0.037231
# fee1H                   0.031444
# end_time                0.022861
# Name: class_117, dtype: float64
#
# ▶ class_118 기여도 상위 5개 피처
# end_time                  0.168806
# Weekday_operatingHours    0.094150
# bus_r300                  0.025746
# total_parking_spaces      0.024799
# cctv_r300                 0.022051
# Name: class_118, dtype: float64
#
# ▶ class_119 기여도 상위 5개 피처
# fee1H                     0.137031
# end_time                  0.053852
# cctv_r300                 0.038911
# bus_r300                  0.036475
# Weekday_operatingHours    0.032353
# Name: class_119, dtype: float64
#
# ▶ class_120 기여도 상위 5개 피처
# Weekday_operatingHours    0.083231
# start_time                0.075475
# cctv_r300                 0.074941
# end_time                  0.066713
# fee1H                     0.039102
# Name: class_120, dtype: float64
#
# ▶ class_121 기여도 상위 5개 피처
# cctv_r300               0.074250
# fee1H                   0.074183
# bus_r300                0.047374
# total_parking_spaces    0.043882
# end_time                0.027638
# Name: class_121, dtype: float64
#
# ▶ class_122 기여도 상위 5개 피처
# total_parking_spaces    0.162016
# bus_r300                0.122582
# fee1H                   0.050758
# cctv_r300               0.034660
# end_time                0.034460
# Name: class_122, dtype: float64
#
# ▶ class_123 기여도 상위 5개 피처
# end_time                  0.109166
# cctv_r300                 0.054439
# Weekday_operatingHours    0.053312
# total_parking_spaces      0.044622
# bus_r300                  0.031419
# Name: class_123, dtype: float64
#
# ▶ class_124 기여도 상위 5개 피처
# bus_r300                  0.151736
# end_time                  0.068732
# Weekday_operatingHours    0.063094
# start_time                0.048602
# fee1H                     0.017548
# Name: class_124, dtype: float64
#
# ▶ class_125 기여도 상위 5개 피처
# fee1H                   0.103216
# total_parking_spaces    0.084678
# bus_r300                0.083951
# cctv_r300               0.068107
# end_time                0.029840
# Name: class_125, dtype: float64
#
# ▶ class_126 기여도 상위 5개 피처
# fee1H                   0.124587
# total_parking_spaces    0.117133
# bus_r300                0.060105
# cctv_r300               0.046231
# end_time                0.038968
# Name: class_126, dtype: float64
#
# ▶ class_127 기여도 상위 5개 피처
# bus_r300                  0.107845
# end_time                  0.061725
# fee1H                     0.056808
# cctv_r300                 0.051782
# Weekday_operatingHours    0.040384
# Name: class_127, dtype: float64
#
# ▶ class_128 기여도 상위 5개 피처
# cctv_r300                 0.108469
# fee1H                     0.064096
# end_time                  0.062463
# Weekday_operatingHours    0.061771
# total_parking_spaces      0.035731
# Name: class_128, dtype: float64
#
# ▶ class_129 기여도 상위 5개 피처
# total_parking_spaces      0.115178
# bus_r300                  0.099734
# cctv_r300                 0.099061
# end_time                  0.037775
# Weekday_operatingHours    0.026052
# Name: class_129, dtype: float64
#
# ▶ class_130 기여도 상위 5개 피처
# end_time                  0.114519
# cctv_r300                 0.106727
# Weekday_operatingHours    0.071138
# bus_r300                  0.032025
# fee1H                     0.024679
# Name: class_130, dtype: float64
#
# ▶ class_131 기여도 상위 5개 피처
# fee1H                   0.137845
# cctv_r300               0.092661
# bus_r300                0.059865
# total_parking_spaces    0.021428
# operation_type          0.017054
# Name: class_131, dtype: float64
#
# ▶ class_132 기여도 상위 5개 피처
# cctv_r300               0.125079
# end_time                0.056542
# bus_r300                0.051459
# total_parking_spaces    0.040064
# operation_type          0.031911
# Name: class_132, dtype: float64
#
# ▶ class_133 기여도 상위 5개 피처
# fee1H                     0.144879
# end_time                  0.068830
# total_parking_spaces      0.064204
# cctv_r300                 0.051460
# Weekday_operatingHours    0.031208
# Name: class_133, dtype: float64
#
# ▶ class_134 기여도 상위 5개 피처
# end_time                  0.145271
# fee1H                     0.105392
# Weekday_operatingHours    0.064935
# total_parking_spaces      0.022466
# bus_r300                  0.018847
# Name: class_134, dtype: float64
#
# ▶ class_135 기여도 상위 5개 피처
# end_time                  0.115841
# fee1H                     0.071090
# total_parking_spaces      0.071059
# Weekday_operatingHours    0.028901
# start_time                0.023862
# Name: class_135, dtype: float64
#
# ▶ class_136 기여도 상위 5개 피처
# fee1H                     0.064941
# end_time                  0.059780
# cctv_r300                 0.050963
# Weekday_operatingHours    0.034618
# start_time                0.019077
# Name: class_136, dtype: float64
#
# ▶ class_137 기여도 상위 5개 피처
# end_time                  0.093583
# cctv_r300                 0.084206
# total_parking_spaces      0.066878
# Weekday_operatingHours    0.046475
# start_time                0.044562
# Name: class_137, dtype: float64
#
# ▶ class_138 기여도 상위 5개 피처
# end_time                  0.127382
# cctv_r300                 0.082388
# Weekday_operatingHours    0.064738
# fee1H                     0.062247
# operation_type            0.014059
# Name: class_138, dtype: float64
#
# ▶ class_139 기여도 상위 5개 피처
# end_time                  0.143808
# fee1H                     0.092472
# Weekday_operatingHours    0.066235
# operation_type            0.023363
# bus_r300                  0.016247
# Name: class_139, dtype: float64
#
# ▶ class_140 기여도 상위 5개 피처
# end_time                  0.072825
# total_parking_spaces      0.072656
# start_time                0.058451
# Weekday_operatingHours    0.054695
# fee1H                     0.045866
# Name: class_140, dtype: float64
#
# ▶ class_141 기여도 상위 5개 피처
# total_parking_spaces    0.073195
# end_time                0.068261
# fee1H                   0.062169
# bus_r300                0.058165
# cctv_r300               0.056902
# Name: class_141, dtype: float64
#
# ▶ class_142 기여도 상위 5개 피처
# bus_r300                0.101614
# end_time                0.086767
# total_parking_spaces    0.086394
# fee1H                   0.059295
# cctv_r300               0.045378
# Name: class_142, dtype: float64
#
# ▶ class_143 기여도 상위 5개 피처
# fee1H                     0.109125
# end_time                  0.071327
# total_parking_spaces      0.070387
# cctv_r300                 0.040777
# Weekday_operatingHours    0.040519
# Name: class_143, dtype: float64
#
# ▶ class_144 기여도 상위 5개 피처
# end_time                  0.138805
# fee1H                     0.094103
# Weekday_operatingHours    0.062195
# total_parking_spaces      0.024428
# bus_r300                  0.021566
# Name: class_144, dtype: float64
#
# ▶ class_145 기여도 상위 5개 피처
# end_time                  0.139974
# fee1H                     0.101861
# Weekday_operatingHours    0.073898
# operation_type            0.020827
# bus_r300                  0.017554
# Name: class_145, dtype: float64
#
# ▶ class_146 기여도 상위 5개 피처
# fee1H                     0.083440
# Weekday_operatingHours    0.072339
# start_time                0.070446
# end_time                  0.069924
# cctv_r300                 0.053909
# Name: class_146, dtype: float64
#
# ▶ class_147 기여도 상위 5개 피처
# total_parking_spaces      0.115178
# bus_r300                  0.099734
# cctv_r300                 0.099061
# end_time                  0.037775
# Weekday_operatingHours    0.026052
# Name: class_147, dtype: float64
#
# ▶ class_148 기여도 상위 5개 피처
# fee1H                   0.101770
# total_parking_spaces    0.093109
# bus_r300                0.061881
# cctv_r300               0.060288
# end_time                0.029120
# Name: class_148, dtype: float64
#
# ▶ class_149 기여도 상위 5개 피처
# cctv_r300               0.120557
# total_parking_spaces    0.076745
# bus_r300                0.069688
# fee1H                   0.054143
# end_time                0.033109
# Name: class_149, dtype: float64
#
# ▶ class_150 기여도 상위 5개 피처
# total_parking_spaces      0.085667
# cctv_r300                 0.049346
# end_time                  0.048295
# bus_r300                  0.037284
# Weekday_operatingHours    0.034995
# Name: class_150, dtype: float64
#
# ▶ class_151 기여도 상위 5개 피처
# total_parking_spaces      0.153026
# bus_r300                  0.110961
# fee1H                     0.084895
# end_time                  0.029552
# Weekday_operatingHours    0.024818
# Name: class_151, dtype: float64
#
# ▶ class_152 기여도 상위 5개 피처
# end_time                  0.119663
# cctv_r300                 0.073531
# Weekday_operatingHours    0.059791
# fee1H                     0.049234
# bus_r300                  0.045947
# Name: class_152, dtype: float64
#
# ▶ class_153 기여도 상위 5개 피처
# cctv_r300               0.061222
# total_parking_spaces    0.048742
# end_time                0.043504
# fee1H                   0.042455
# bus_r300                0.029553
# Name: class_153, dtype: float64
#
# ▶ class_154 기여도 상위 5개 피처
# end_time                  0.120912
# fee1H                     0.093308
# Weekday_operatingHours    0.059432
# bus_r300                  0.052179
# operation_type            0.036464
# Name: class_154, dtype: float64
#
# ▶ class_155 기여도 상위 5개 피처
# end_time                  0.143089
# Weekday_operatingHours    0.072436
# fee1H                     0.046244
# cctv_r300                 0.045017
# bus_r300                  0.041422
# Name: class_155, dtype: float64
#
# ▶ class_156 기여도 상위 5개 피처
# total_parking_spaces    0.129664
# fee1H                   0.066272
# end_time                0.065163
# bus_r300                0.036117
# start_time              0.035387
# Name: class_156, dtype: float64
#
# ▶ class_157 기여도 상위 5개 피처
# end_time                  0.063176
# fee1H                     0.050207
# Weekday_operatingHours    0.040350
# total_parking_spaces      0.036586
# cctv_r300                 0.034746
# Name: class_157, dtype: float64
#
# ▶ class_158 기여도 상위 5개 피처
# end_time                  0.129507
# fee1H                     0.088349
# Weekday_operatingHours    0.064418
# bus_r300                  0.029732
# operation_type            0.024902
# Name: class_158, dtype: float64
#
# ▶ class_159 기여도 상위 5개 피처
# end_time                  0.146894
# fee1H                     0.081966
# Weekday_operatingHours    0.068787
# operation_type            0.021665
# bus_r300                  0.021172
# Name: class_159, dtype: float64
#
# ▶ class_160 기여도 상위 5개 피처
# cctv_r300                 0.120776
# fee1H                     0.092543
# bus_r300                  0.082749
# total_parking_spaces      0.077217
# Weekday_operatingHours    0.021130
# Name: class_160, dtype: float64
#
# ▶ class_161 기여도 상위 5개 피처
# bus_r300                  0.112171
# Weekday_operatingHours    0.073737
# end_time                  0.061170
# start_time                0.055033
# fee1H                     0.043554
# Name: class_161, dtype: float64
#
# ▶ class_162 기여도 상위 5개 피처
# bus_r300                  0.107845
# end_time                  0.061725
# fee1H                     0.056808
# cctv_r300                 0.051782
# Weekday_operatingHours    0.040384
# Name: class_162, dtype: float64
#
# ▶ class_163 기여도 상위 5개 피처
# bus_r300                  0.080697
# total_parking_spaces      0.068560
# cctv_r300                 0.067620
# end_time                  0.064050
# Weekday_operatingHours    0.047836
# Name: class_163, dtype: float64
#
# ▶ class_164 기여도 상위 5개 피처
# total_parking_spaces      0.106797
# Weekday_operatingHours    0.086176
# end_time                  0.070574
# cctv_r300                 0.052722
# fee1H                     0.034418
# Name: class_164, dtype: float64
#
# ▶ class_165 기여도 상위 5개 피처
# end_time                  0.086930
# bus_r300                  0.078345
# Weekday_operatingHours    0.056463
# fee1H                     0.046826
# cctv_r300                 0.021077
# Name: class_165, dtype: float64
#
# ▶ class_166 기여도 상위 5개 피처
# fee1H                   0.110026
# bus_r300                0.080837
# total_parking_spaces    0.068254
# cctv_r300               0.050232
# end_time                0.024018
# Name: class_166, dtype: float64
#
# ▶ class_167 기여도 상위 5개 피처
# fee1H                     0.093348
# bus_r300                  0.083851
# total_parking_spaces      0.053320
# end_time                  0.048427
# Weekday_operatingHours    0.038154
# Name: class_167, dtype: float64
#
# ▶ class_168 기여도 상위 5개 피처
# total_parking_spaces    0.262920
# bus_r300                0.064629
# fee1H                   0.056156
# cctv_r300               0.038068
# end_time                0.022479
# Name: class_168, dtype: float64
#
# ▶ class_169 기여도 상위 5개 피처
# end_time                  0.133029
# Weekday_operatingHours    0.049520
# total_parking_spaces      0.044359
# start_time                0.043301
# bus_r300                  0.024368
# Name: class_169, dtype: float64
#
# ▶ class_170 기여도 상위 5개 피처
# end_time                  0.143542
# fee1H                     0.110653
# Weekday_operatingHours    0.069496
# bus_r300                  0.027800
# operation_type            0.017569
# Name: class_170, dtype: float64
#
# ▶ class_171 기여도 상위 5개 피처
# cctv_r300                 0.119023
# end_time                  0.070496
# total_parking_spaces      0.061992
# bus_r300                  0.043268
# Weekday_operatingHours    0.038617
# Name: class_171, dtype: float64
#
# ▶ class_172 기여도 상위 5개 피처
# total_parking_spaces      0.074015
# bus_r300                  0.059957
# fee1H                     0.055737
# end_time                  0.053590
# Weekday_operatingHours    0.041936
# Name: class_172, dtype: float64
#
# ▶ class_173 기여도 상위 5개 피처
# cctv_r300                 0.103866
# bus_r300                  0.066919
# total_parking_spaces      0.056921
# end_time                  0.055515
# Weekday_operatingHours    0.036250
# Name: class_173, dtype: float64
#
# ▶ class_174 기여도 상위 5개 피처
# end_time                  0.096635
# Weekday_operatingHours    0.058518
# cctv_r300                 0.057835
# start_time                0.034061
# fee1H                     0.020125
# Name: class_174, dtype: float64
#
# ▶ class_175 기여도 상위 5개 피처
# cctv_r300                 0.097668
# end_time                  0.064623
# bus_r300                  0.040056
# Weekday_operatingHours    0.037446
# fee1H                     0.036817
# Name: class_175, dtype: float64
#
# ▶ class_176 기여도 상위 5개 피처
# total_parking_spaces    0.131378
# bus_r300                0.092488
# cctv_r300               0.090546
# fee1H                   0.049442
# end_time                0.032928
# Name: class_176, dtype: float64
#
# ▶ class_177 기여도 상위 5개 피처
# end_time                  0.105859
# bus_r300                  0.091685
# total_parking_spaces      0.076439
# Weekday_operatingHours    0.058536
# cctv_r300                 0.029318
# Name: class_177, dtype: float64
#
# ▶ class_178 기여도 상위 5개 피처
# cctv_r300                 0.132401
# bus_r300                  0.127932
# fee1H                     0.051549
# end_time                  0.038408
# Weekday_operatingHours    0.028633
# Name: class_178, dtype: float64
#
# ▶ class_179 기여도 상위 5개 피처
# end_time                  0.143081
# fee1H                     0.088969
# Weekday_operatingHours    0.069681
# operation_type            0.019326
# bus_r300                  0.016859
# Name: class_179, dtype: float64
#
# ▶ class_180 기여도 상위 5개 피처
# bus_r300                0.065102
# cctv_r300               0.065083
# end_time                0.056722
# total_parking_spaces    0.051321
# fee1H                   0.042414
# Name: class_180, dtype: float64
#
# ▶ class_181 기여도 상위 5개 피처
# end_time                  0.134733
# fee1H                     0.081798
# Weekday_operatingHours    0.063545
# bus_r300                  0.051265
# operation_type            0.017444
# Name: class_181, dtype: float64
#
# ▶ class_182 기여도 상위 5개 피처
# cctv_r300                 0.125440
# total_parking_spaces      0.068944
# fee1H                     0.061154
# end_time                  0.052197
# Weekday_operatingHours    0.032926
# Name: class_182, dtype: float64
#
# ▶ class_183 기여도 상위 5개 피처
# total_parking_spaces    0.089703
# bus_r300                0.053712
# end_time                0.052208
# cctv_r300               0.049505
# fee1H                   0.048296
# Name: class_183, dtype: float64
#
# ▶ class_184 기여도 상위 5개 피처
# total_parking_spaces      0.083568
# fee1H                     0.077785
# end_time                  0.067290
# cctv_r300                 0.042620
# Weekday_operatingHours    0.034991
# Name: class_184, dtype: float64
#
# ▶ class_185 기여도 상위 5개 피처
# cctv_r300                 0.145610
# bus_r300                  0.087782
# end_time                  0.063277
# total_parking_spaces      0.047036
# Weekday_operatingHours    0.034950
# Name: class_185, dtype: float64
#
# ▶ class_186 기여도 상위 5개 피처
# total_parking_spaces    0.118271
# bus_r300                0.074268
# cctv_r300               0.069596
# fee1H                   0.065227
# start_time              0.023154
# Name: class_186, dtype: float64
#
# ▶ class_187 기여도 상위 5개 피처
# end_time                  0.124997
# fee1H                     0.085035
# bus_r300                  0.064958
# Weekday_operatingHours    0.059287
# operation_type            0.023344
# Name: class_187, dtype: float64
#
# ▶ class_188 기여도 상위 5개 피처
# total_parking_spaces      0.156716
# Weekday_operatingHours    0.063715
# end_time                  0.063709
# start_time                0.048372
# fee1H                     0.040551
# Name: class_188, dtype: float64
#
# ▶ class_189 기여도 상위 5개 피처
# end_time                  0.091819
# cctv_r300                 0.085561
# fee1H                     0.071496
# Weekday_operatingHours    0.058517
# bus_r300                  0.054781
# Name: class_189, dtype: float64
#
# ▶ class_190 기여도 상위 5개 피처
# bus_r300                  0.125378
# Weekday_operatingHours    0.070573
# end_time                  0.067458
# start_time                0.053588
# cctv_r300                 0.038787
# Name: class_190, dtype: float64
#
# ▶ class_191 기여도 상위 5개 피처
# fee1H                     0.108434
# end_time                  0.046821
# Weekday_operatingHours    0.043799
# bus_r300                  0.042330
# total_parking_spaces      0.042076
# Name: class_191, dtype: float64
#
# ▶ class_192 기여도 상위 5개 피처
# bus_r300                  0.082669
# end_time                  0.060308
# cctv_r300                 0.051499
# fee1H                     0.038172
# Weekday_operatingHours    0.036252
# Name: class_192, dtype: float64
#
# ▶ class_193 기여도 상위 5개 피처
# end_time                  0.061654
# fee1H                     0.060246
# total_parking_spaces      0.049942
# cctv_r300                 0.049478
# Weekday_operatingHours    0.037634
# Name: class_193, dtype: float64
#
# ▶ class_194 기여도 상위 5개 피처
# total_parking_spaces    0.097540
# bus_r300                0.061157
# cctv_r300               0.050097
# end_time                0.049592
# fee1H                   0.042822
# Name: class_194, dtype: float64
#
# ▶ class_195 기여도 상위 5개 피처
# fee1H                     0.079427
# end_time                  0.055498
# total_parking_spaces      0.050556
# bus_r300                  0.047449
# Weekday_operatingHours    0.037742
# Name: class_195, dtype: float64
#
# ▶ class_196 기여도 상위 5개 피처
# end_time                  0.083179
# bus_r300                  0.070776
# Weekday_operatingHours    0.067882
# fee1H                     0.050982
# total_parking_spaces      0.046616
# Name: class_196, dtype: float64
#
# ▶ class_197 기여도 상위 5개 피처
# cctv_r300                 0.141700
# end_time                  0.054713
# fee1H                     0.050620
# total_parking_spaces      0.049429
# Weekday_operatingHours    0.037382
# Name: class_197, dtype: float64
#
# ▶ class_198 기여도 상위 5개 피처
# end_time                  0.138951
# fee1H                     0.092457
# Weekday_operatingHours    0.068584
# total_parking_spaces      0.031490
# bus_r300                  0.020353
# Name: class_198, dtype: float64
#
# ▶ class_199 기여도 상위 5개 피처
# end_time                  0.133994
# Weekday_operatingHours    0.063953
# cctv_r300                 0.039303
# operation_type            0.037086
# bus_r300                  0.030719
# Name: class_199, dtype: float64
#
# ▶ class_200 기여도 상위 5개 피처
# cctv_r300                 0.062777
# end_time                  0.047000
# total_parking_spaces      0.037331
# Weekday_operatingHours    0.026638
# fee1H                     0.025366
# Name: class_200, dtype: float64
#
# ▶ class_201 기여도 상위 5개 피처
# fee1H                     0.073071
# end_time                  0.057263
# Weekday_operatingHours    0.033668
# total_parking_spaces      0.028423
# start_time                0.026123
# Name: class_201, dtype: float64
#
# ▶ class_202 기여도 상위 5개 피처
# total_parking_spaces    0.139586
# fee1H                   0.113242
# bus_r300                0.085798
# cctv_r300               0.039375
# start_time              0.012340
# Name: class_202, dtype: float64
#
# ▶ class_203 기여도 상위 5개 피처
# cctv_r300                 0.123503
# end_time                  0.076533
# total_parking_spaces      0.055624
# Weekday_operatingHours    0.045473
# operation_type            0.042551
# Name: class_203, dtype: float64
#
# ▶ class_204 기여도 상위 5개 피처
# total_parking_spaces      0.062686
# end_time                  0.059029
# bus_r300                  0.055593
# Weekday_operatingHours    0.050896
# start_time                0.050425
# Name: class_204, dtype: float64
#
# ▶ class_205 기여도 상위 5개 피처
# bus_r300                0.195473
# total_parking_spaces    0.078225
# fee1H                   0.073320
# cctv_r300               0.037662
# end_time                0.024918
# Name: class_205, dtype: float64
#
# ▶ class_206 기여도 상위 5개 피처
# total_parking_spaces      0.115948
# end_time                  0.063883
# bus_r300                  0.062462
# cctv_r300                 0.056913
# Weekday_operatingHours    0.047046
# Name: class_206, dtype: float64
#
# ▶ class_207 기여도 상위 5개 피처
# cctv_r300                 0.096419
# Weekday_operatingHours    0.073488
# bus_r300                  0.070091
# end_time                  0.061457
# start_time                0.058346
# Name: class_207, dtype: float64
#
# ▶ class_208 기여도 상위 5개 피처
# fee1H                     0.108434
# end_time                  0.046821
# Weekday_operatingHours    0.043799
# bus_r300                  0.042330
# total_parking_spaces      0.042076
# Name: class_208, dtype: float64
#
# ▶ class_209 기여도 상위 5개 피처
# total_parking_spaces    0.103515
# bus_r300                0.100128
# ...
# end_time                  0.110806
# Weekday_operatingHours    0.058113
# cctv_r300                 0.052019
# bus_r300                  0.038501
# total_parking_spaces      0.035036
# Name: class_1002, dtype: float64
#
# ▶ class_1003 기여도 상위 5개 피처
# bus_r300                0.187745
# cctv_r300               0.125808
# total_parking_spaces    0.044406
# fee1H                   0.044336
# end_time                0.020346
# Name: class_1003, dtype: float64
#
# ▶ class_1004 기여도 상위 5개 피처
# fee1H                     0.084791
# end_time                  0.055865
# Weekday_operatingHours    0.041067
# cctv_r300                 0.032716
# bus_r300                  0.031136
# Name: class_1004, dtype: float64
#
# ▶ class_1005 기여도 상위 5개 피처
# end_time                  0.120880
# fee1H                     0.063952
# Weekday_operatingHours    0.061975
# bus_r300                  0.056973
# cctv_r300                 0.056758
# Name: class_1005, dtype: float64
#
# ▶ class_1006 기여도 상위 5개 피처
# fee1H                   0.180772
# cctv_r300               0.041235
# end_time                0.017295
# bus_r300                0.016924
# total_parking_spaces    0.014658
# Name: class_1006, dtype: float64
#
# ▶ class_1007 기여도 상위 5개 피처
# fee1H                     0.104961
# operation_type            0.084455
# end_time                  0.079809
# Weekday_operatingHours    0.035437
# total_parking_spaces      0.034834
# Name: class_1007, dtype: float64
#
# ▶ class_1008 기여도 상위 5개 피처
# cctv_r300                 0.153046
# end_time                  0.059130
# total_parking_spaces      0.055902
# fee1H                     0.041383
# Weekday_operatingHours    0.037570
# Name: class_1008, dtype: float64
#
# ▶ class_1009 기여도 상위 5개 피처
# end_time                  0.126309
# fee1H                     0.089324
# total_parking_spaces      0.081809
# Weekday_operatingHours    0.059589
# cctv_r300                 0.013435
# Name: class_1009, dtype: float64
#
# ▶ class_1010 기여도 상위 5개 피처
# end_time                  0.111910
# cctv_r300                 0.094468
# Weekday_operatingHours    0.060274
# bus_r300                  0.042246
# total_parking_spaces      0.036084
# Name: class_1010, dtype: float64
#
# ▶ class_1011 기여도 상위 5개 피처
# total_parking_spaces      0.059369
# end_time                  0.049997
# bus_r300                  0.044222
# cctv_r300                 0.043127
# Weekday_operatingHours    0.042712
# Name: class_1011, dtype: float64
#
# ▶ class_1012 기여도 상위 5개 피처
# end_time                  0.076620
# total_parking_spaces      0.061412
# cctv_r300                 0.036734
# Weekday_operatingHours    0.035583
# bus_r300                  0.035391
# Name: class_1012, dtype: float64
#
# ▶ class_1013 기여도 상위 5개 피처
# bus_r300                  0.088205
# Weekday_operatingHours    0.076530
# end_time                  0.070845
# start_time                0.064164
# fee1H                     0.050828
# Name: class_1013, dtype: float64
#
# ▶ class_1014 기여도 상위 5개 피처
# cctv_r300                 0.111320
# fee1H                     0.065859
# bus_r300                  0.061484
# Weekday_operatingHours    0.047380
# end_time                  0.047003
# Name: class_1014, dtype: float64
#
# ▶ class_1015 기여도 상위 5개 피처
# end_time                  0.062792
# Weekday_operatingHours    0.044722
# bus_r300                  0.037008
# total_parking_spaces      0.035266
# start_time                0.032713
# Name: class_1015, dtype: float64
#
# ▶ class_1016 기여도 상위 5개 피처
# fee1H                     0.143351
# total_parking_spaces      0.107406
# bus_r300                  0.082969
# cctv_r300                 0.055011
# Weekday_operatingHours    0.025341
# Name: class_1016, dtype: float64
#
# ▶ class_1017 기여도 상위 5개 피처
# bus_r300                  0.106199
# total_parking_spaces      0.077339
# end_time                  0.067519
# Weekday_operatingHours    0.042689
# start_time                0.015277
# Name: class_1017, dtype: float64
#
# ▶ class_1018 기여도 상위 5개 피처
# end_time                  0.113135
# fee1H                     0.108020
# Weekday_operatingHours    0.062157
# total_parking_spaces      0.021508
# operation_type            0.016317
# Name: class_1018, dtype: float64
#
# ▶ class_1019 기여도 상위 5개 피처
# cctv_r300               0.100926
# bus_r300                0.071804
# fee1H                   0.060778
# end_time                0.049335
# total_parking_spaces    0.048697
# Name: class_1019, dtype: float64
#
# ▶ class_1020 기여도 상위 5개 피처
# total_parking_spaces      0.175661
# end_time                  0.048521
# cctv_r300                 0.042408
# fee1H                     0.039259
# Weekday_operatingHours    0.031177
# Name: class_1020, dtype: float64
#
# ▶ class_1021 기여도 상위 5개 피처
# cctv_r300               0.108998
# fee1H                   0.107212
# bus_r300                0.065003
# total_parking_spaces    0.064422
# end_time                0.033514
# Name: class_1021, dtype: float64
#
# ▶ class_1022 기여도 상위 5개 피처
# fee1H                   0.117147
# cctv_r300               0.109785
# total_parking_spaces    0.053651
# end_time                0.019702
# bus_r300                0.017242
# Name: class_1022, dtype: float64
#
# ▶ class_1023 기여도 상위 5개 피처
# fee1H                   0.074878
# cctv_r300               0.064212
# total_parking_spaces    0.060652
# operation_type          0.055589
# bus_r300                0.053627
# Name: class_1023, dtype: float64
#
# ▶ class_1024 기여도 상위 5개 피처
# cctv_r300                 0.162058
# Weekday_operatingHours    0.060347
# end_time                  0.059167
# start_time                0.051579
# bus_r300                  0.041153
# Name: class_1024, dtype: float64
#
# ▶ class_1025 기여도 상위 5개 피처
# fee1H                   0.162100
# total_parking_spaces    0.102007
# bus_r300                0.095868
# cctv_r300               0.082399
# end_time                0.026286
# Name: class_1025, dtype: float64
#
# ▶ class_1026 기여도 상위 5개 피처
# end_time                  0.077783
# cctv_r300                 0.063243
# total_parking_spaces      0.049767
# Weekday_operatingHours    0.048143
# fee1H                     0.038164
# Name: class_1026, dtype: float64
#
# ▶ class_1027 기여도 상위 5개 피처
# fee1H                     0.090534
# total_parking_spaces      0.064361
# bus_r300                  0.059494
# end_time                  0.056993
# Weekday_operatingHours    0.039257
# Name: class_1027, dtype: float64
#
# ▶ class_1028 기여도 상위 5개 피처
# cctv_r300                 0.093590
# end_time                  0.064376
# Weekday_operatingHours    0.056232
# start_time                0.053525
# total_parking_spaces      0.039132
# Name: class_1028, dtype: float64
#
# ▶ class_1029 기여도 상위 5개 피처
# bus_r300                0.179970
# cctv_r300               0.134736
# total_parking_spaces    0.100484
# fee1H                   0.036440
# end_time                0.025045
# Name: class_1029, dtype: float64
#
# ▶ class_1030 기여도 상위 5개 피처
# fee1H                     0.131028
# end_time                  0.040536
# cctv_r300                 0.033800
# bus_r300                  0.027046
# Weekday_operatingHours    0.025474
# Name: class_1030, dtype: float64
#
# ▶ class_1031 기여도 상위 5개 피처
# end_time                  0.076880
# total_parking_spaces      0.066825
# fee1H                     0.046140
# bus_r300                  0.039427
# Weekday_operatingHours    0.037919
# Name: class_1031, dtype: float64
#
# ▶ class_1032 기여도 상위 5개 피처
# end_time                0.074785
# total_parking_spaces    0.057499
# bus_r300                0.057095
# start_time              0.051701
# fee1H                   0.039278
# Name: class_1032, dtype: float64
#
# ▶ class_1033 기여도 상위 5개 피처
# fee1H                   0.098318
# bus_r300                0.074028
# total_parking_spaces    0.057968
# end_time                0.046434
# cctv_r300               0.042623
# Name: class_1033, dtype: float64
#
# ▶ class_1034 기여도 상위 5개 피처
# end_time                0.074614
# total_parking_spaces    0.067418
# cctv_r300               0.060726
# fee1H                   0.056484
# bus_r300                0.052110
# Name: class_1034, dtype: float64
#
# ▶ class_1035 기여도 상위 5개 피처
# end_time                  0.111296
# Weekday_operatingHours    0.062112
# fee1H                     0.044978
# bus_r300                  0.038013
# start_time                0.030846
# Name: class_1035, dtype: float64
#
# ▶ class_1036 기여도 상위 5개 피처
# cctv_r300                 0.080374
# bus_r300                  0.066212
# end_time                  0.064504
# Weekday_operatingHours    0.047127
# total_parking_spaces      0.043242
# Name: class_1036, dtype: float64
#
# ▶ class_1037 기여도 상위 5개 피처
# end_time                  0.072817
# total_parking_spaces      0.057766
# cctv_r300                 0.053984
# Weekday_operatingHours    0.047633
# start_time                0.032829
# Name: class_1037, dtype: float64
#
# ▶ class_1038 기여도 상위 5개 피처
# cctv_r300               0.130081
# bus_r300                0.105131
# total_parking_spaces    0.091113
# fee1H                   0.039294
# end_time                0.025672
# Name: class_1038, dtype: float64
#
# ▶ class_1039 기여도 상위 5개 피처
# total_parking_spaces    0.271204
# fee1H                   0.070386
# bus_r300                0.051582
# cctv_r300               0.036930
# end_time                0.025107
# Name: class_1039, dtype: float64
#
# ▶ class_1040 기여도 상위 5개 피처
# bus_r300                0.147649
# cctv_r300               0.095001
# total_parking_spaces    0.085885
# fee1H                   0.060525
# end_time                0.021434
# Name: class_1040, dtype: float64
#
# ▶ class_1041 기여도 상위 5개 피처
# end_time                  0.051316
# fee1H                     0.049760
# bus_r300                  0.048913
# cctv_r300                 0.033142
# Weekday_operatingHours    0.029449
# Name: class_1041, dtype: float64
#
# ▶ class_1042 기여도 상위 5개 피처
# end_time                  0.090957
# bus_r300                  0.081026
# Weekday_operatingHours    0.047570
# fee1H                     0.043525
# total_parking_spaces      0.032444
# Name: class_1042, dtype: float64
#
# ▶ class_1043 기여도 상위 5개 피처
# total_parking_spaces    0.070863
# cctv_r300               0.062387
# end_time                0.049658
# fee1H                   0.041456
# bus_r300                0.038775
# Name: class_1043, dtype: float64
#
# ▶ class_1044 기여도 상위 5개 피처
# total_parking_spaces      0.079291
# fee1H                     0.072211
# end_time                  0.063815
# Weekday_operatingHours    0.052293
# start_time                0.033623
# Name: class_1044, dtype: float64
#
# ▶ class_1045 기여도 상위 5개 피처
# cctv_r300                 0.117266
# bus_r300                  0.075865
# end_time                  0.056767
# total_parking_spaces      0.050014
# Weekday_operatingHours    0.035351
# Name: class_1045, dtype: float64
#
# ▶ class_1046 기여도 상위 5개 피처
# total_parking_spaces      0.101579
# start_time                0.064983
# Weekday_operatingHours    0.062844
# end_time                  0.051373
# fee1H                     0.027341
# Name: class_1046, dtype: float64
#
# ▶ class_1047 기여도 상위 5개 피처
# end_time                  0.140301
# fee1H                     0.088809
# Weekday_operatingHours    0.065348
# operation_type            0.027379
# bus_r300                  0.026239
# Name: class_1047, dtype: float64
#
# ▶ class_1048 기여도 상위 5개 피처
# cctv_r300                 0.074980
# end_time                  0.063643
# bus_r300                  0.058778
# total_parking_spaces      0.048626
# Weekday_operatingHours    0.042227
# Name: class_1048, dtype: float64
#
# ▶ class_1049 기여도 상위 5개 피처
# end_time                0.071370
# fee1H                   0.067318
# bus_r300                0.049146
# total_parking_spaces    0.047895
# cctv_r300               0.045615
# Name: class_1049, dtype: float64
#
# ▶ class_1050 기여도 상위 5개 피처
# total_parking_spaces    0.094042
# cctv_r300               0.082573
# bus_r300                0.059020
# end_time                0.049913
# operation_type          0.035135
# Name: class_1050, dtype: float64
#
# ▶ class_1051 기여도 상위 5개 피처
# end_time                  0.121467
# fee1H                     0.071620
# Weekday_operatingHours    0.061889
# cctv_r300                 0.061149
# bus_r300                  0.033416
# Name: class_1051, dtype: float64
#
# ▶ class_1052 기여도 상위 5개 피처
# fee1H                     0.088514
# bus_r300                  0.049647
# end_time                  0.044575
# Weekday_operatingHours    0.040209
# start_time                0.035051
# Name: class_1052, dtype: float64
#
# ▶ class_1053 기여도 상위 5개 피처
# cctv_r300               0.114847
# bus_r300                0.075129
# fee1H                   0.072709
# total_parking_spaces    0.061544
# end_time                0.028592
# Name: class_1053, dtype: float64
#
# ▶ class_1054 기여도 상위 5개 피처
# cctv_r300                 0.081896
# end_time                  0.065136
# start_time                0.052776
# Weekday_operatingHours    0.046640
# bus_r300                  0.043403
# Name: class_1054, dtype: float64
#
# ▶ class_1055 기여도 상위 5개 피처
# end_time                  0.070614
# cctv_r300                 0.051253
# bus_r300                  0.043623
# Weekday_operatingHours    0.042666
# fee1H                     0.041760
# Name: class_1055, dtype: float64
#
# ▶ class_1056 기여도 상위 5개 피처
# fee1H                   0.093503
# cctv_r300               0.093193
# total_parking_spaces    0.085988
# bus_r300                0.052174
# end_time                0.033459
# Name: class_1056, dtype: float64
#
# ▶ class_1057 기여도 상위 5개 피처
# fee1H                     0.088742
# total_parking_spaces      0.055498
# end_time                  0.041820
# Weekday_operatingHours    0.038545
# bus_r300                  0.030921
# Name: class_1057, dtype: float64
#
# ▶ class_1058 기여도 상위 5개 피처
# Weekday_operatingHours    0.086824
# cctv_r300                 0.055849
# start_time                0.050352
# total_parking_spaces      0.038152
# fee1H                     0.036860
# Name: class_1058, dtype: float64
#
# ▶ class_1059 기여도 상위 5개 피처
# total_parking_spaces      0.158254
# Weekday_operatingHours    0.071843
# cctv_r300                 0.052624
# bus_r300                  0.041544
# start_time                0.040423
# Name: class_1059, dtype: float64
#
# ▶ class_1060 기여도 상위 5개 피처
# bus_r300                  0.098699
# Weekday_operatingHours    0.068824
# end_time                  0.064657
# start_time                0.056753
# fee1H                     0.030973
# Name: class_1060, dtype: float64
#
# ▶ class_1061 기여도 상위 5개 피처
# end_time                  0.064114
# bus_r300                  0.059073
# Weekday_operatingHours    0.046899
# start_time                0.040374
# total_parking_spaces      0.025012
# Name: class_1061, dtype: float64
#
# ▶ class_1062 기여도 상위 5개 피처
# end_time                  0.127035
# fee1H                     0.097576
# Weekday_operatingHours    0.065721
# bus_r300                  0.030984
# operation_type            0.030602
# Name: class_1062, dtype: float64
#
# ▶ class_1063 기여도 상위 5개 피처
# fee1H                     0.077174
# end_time                  0.053842
# total_parking_spaces      0.051132
# cctv_r300                 0.042861
# Weekday_operatingHours    0.037958
# Name: class_1063, dtype: float64
#
# ▶ class_1064 기여도 상위 5개 피처
# total_parking_spaces      0.106142
# fee1H                     0.090799
# end_time                  0.050539
# bus_r300                  0.050353
# Weekday_operatingHours    0.028902
# Name: class_1064, dtype: float64
#
# ▶ class_1065 기여도 상위 5개 피처
# end_time                  0.130716
# fee1H                     0.076619
# Weekday_operatingHours    0.067010
# cctv_r300                 0.053354
# total_parking_spaces      0.026557
# Name: class_1065, dtype: float64
#
# ▶ class_1066 기여도 상위 5개 피처
# total_parking_spaces      0.115948
# end_time                  0.063883
# bus_r300                  0.062462
# cctv_r300                 0.056913
# Weekday_operatingHours    0.047046
# Name: class_1066, dtype: float64
#
# ▶ class_1067 기여도 상위 5개 피처
# end_time                  0.068430
# cctv_r300                 0.062768
# fee1H                     0.060022
# Weekday_operatingHours    0.048913
# start_time                0.041450
# Name: class_1067, dtype: float64
#
# ▶ class_1068 기여도 상위 5개 피처
# bus_r300                  0.088715
# end_time                  0.066347
# cctv_r300                 0.048455
# Weekday_operatingHours    0.036944
# fee1H                     0.027810
# Name: class_1068, dtype: float64
#
# ▶ class_1069 기여도 상위 5개 피처
# total_parking_spaces    0.116585
# bus_r300                0.099021
# fee1H                   0.064696
# cctv_r300               0.064305
# end_time                0.036779
# Name: class_1069, dtype: float64
#
# ▶ class_1070 기여도 상위 5개 피처
# end_time                  0.142514
# Weekday_operatingHours    0.077712
# cctv_r300                 0.072681
# bus_r300                  0.023541
# operation_type            0.022548
# Name: class_1070, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
import pandas as pd
pd.set_option('display.max_rows', None)

# 여기 요일타입에 따라 바꿔야 됩니다!!
dong_parks_df = pd.read_csv("src/dongParks_Weekday.csv")
dong_parks_df

# dong_parks_df의 feature 컬럼만 추출 (dong 이름 등 식별자 제외)
# 모델이 학습할 때 사용한 feature 리스트
model_features = list(rf.feature_names_in_)

# dong_parks_df에서 해당 컬럼만 추출
X_dong = dong_parks_df[model_features]
# 동별 민원 수준 예측
dong_parks_df['predicted_complaints'] = rf.predict(X_dong)

# 그룹별 동 이름 추출
high_dong = dong_parks_df[dong_parks_df['predicted_complaints'] == 2]['dong']
mid_dong = dong_parks_df[dong_parks_df['predicted_complaints'] == 1]['dong']
low_dong = dong_parks_df[dong_parks_df['predicted_complaints'] == 0]['dong']

# 각 그룹을 DataFrame으로 변환 (인덱스 리셋)
high_df = pd.DataFrame({'High 민원': high_dong.reset_index(drop=True)})
mid_df = pd.DataFrame({'Mid 민원': mid_dong.reset_index(drop=True)})
low_df = pd.DataFrame({'Low 민원': low_dong.reset_index(drop=True)})

# 길이가 다른 경우도 맞춰서 하나의 표로 합치기
dong_table = pd.concat([high_df, mid_df, low_df], axis=1)

from IPython.display import display
display(dong_table.head())
# Out:
#    High 민원 Mid 민원 Low 민원
# 0     가락본동   가리봉동    가산동
# 1     고덕2동    강일동   가양1동
# 2     구로3동   개포3동   가양2동
# 3     구의1동   거여2동   가양3동
# 4  금호2·3가동    광희동   갈현1동

# %%
import pandas as pd

pd.Series(rf.feature_importances_, index=X_dong.columns).sort_values(ascending=False)
# Out:
# total_parking_spaces      0.223380
# bus_r300                  0.197859
# fee1H                     0.172679
# cctv_r300                 0.160017
# end_cos                   0.061390
# end_sin                   0.054610
# Weekday_operatingHours    0.052322
# operation_type            0.027090
# start_sin                 0.025401
# start_cos                 0.025253
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler


scaler = RobustScaler()
X_scaled = pd.DataFrame(
    scaler.fit_transform(X_dong),
    columns=X_dong.columns
)

'''
# 정규화 수행
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X_dong), columns=X_dong.columns)
'''

# 정규화된 데이터 기준으로 영향력 큰 feature 추정
importances = rf.feature_importances_
dong_parks_df['top_feature'] = X_scaled.apply(
    lambda row: row.index[np.argmax(np.abs(row.values * importances))],
    axis=1
)

# 결과 출력
solution_table = dong_parks_df[['dong', 'predicted_complaints', 'top_feature']]
display(solution_table.head())

# 민원 수준별 요약
summary = solution_table.groupby('predicted_complaints')['top_feature'].value_counts()
print(summary)
# Out:
#    dong  predicted_complaints           top_feature
# 0  가락본동                     2             cctv_r300
# 1  가리봉동                     1  total_parking_spaces
# 2   가산동                     0              bus_r300
# 3  가양1동                     0  total_parking_spaces
# 4  가양2동                     0              bus_r300
# predicted_complaints  top_feature
# 0                     total_parking_spaces    55
#                       fee1H                   53
#                       bus_r300                52
#                       cctv_r300               33
# 1                     fee1H                   31
#                       cctv_r300               18
#                       bus_r300                16
#                       total_parking_spaces     9
# 2                     cctv_r300               18
#                       total_parking_spaces    13
#                       bus_r300                12
#                       fee1H                   11
# Name: count, dtype: int64

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# 1) 행정동 경계 불러오기 (EPSG:5179)
dong_boundaries = (
    gpd.read_file("src/dong_boundary.shp")
       .rename(columns={"ADM_NM":"dong"})
)

# 3) 주소에서 ‘○○동’ 부분만 추출해 두기
parks_df['addr_dong'] = parks_df['address'].str.extract(r'^\S+\s+(\S+동)')[0]

# 4) GeoDataFrame 생성 (위경도 → EPSG:4326 지정)
geometry = [Point(xy) for xy in zip(parks_df['lon'], parks_df['lat'])]
parks_gdf = gpd.GeoDataFrame(
    parks_df,
    geometry=geometry,
    crs="EPSG:4326"
)

# 5) 경계 CRS로 투영
parks_gdf = parks_gdf.to_crs(dong_boundaries.crs)

# ─────── 이 부분을 추가 ───────
# 6) 공간 결합
parks_gdf = gpd.sjoin(
    parks_gdf,
    dong_boundaries[['dong','geometry']],
    how='left',
    predicate='within'
)

# 7) NaN인 경우만 매핑 테이블로 보정
mapping = {
    '잠실동': '잠실본동',
    # 필요시 다른 주소-행정동도 여기에 추가
}
parks_gdf['dong'] = parks_gdf['dong'].fillna(
    parks_gdf['addr_dong'].map(mapping)
)
# ─────────────────────────────

# 8) 결과 확인
parks_gdf = parks_gdf.drop(columns=['addr_dong', 'geometry', 'index_right'])
print(parks_gdf.columns)
# Out:
# Index(['address', 'parking_type', 'operation_type', 'total_parking_spaces',
#        'base_parking_fee', 'base_parking_time', 'additional_unit_fee',
#        'additional_unit_time', 'fee1H', 'cctv_r300', 'bus_r300',
#        'complaints_r300', 'Weekday_paid', 'Weekday_operatingHours', 'lon',
#        'lat', 'zoning_encoded', 'start_sin', 'start_cos', 'end_sin', 'end_cos',
#        'complaint_level', 'dong'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd
import shap

# 1) TreeExplainer 생성
explainer = shap.TreeExplainer(rf)
feature_cols = list(rf.feature_names_in_)

# 2) park-level SHAP 값 계산 (n_samples, n_features, n_classes)
raw_shap_p = explainer.shap_values(parks_gdf[feature_cols])

# 3) 클래스 차원 절댓값 평균 → (n_samples, n_features)
shap_abs_p = np.abs(raw_shap_p).mean(axis=2)

# 4) DataFrame으로 변환 후 dong 매핑
df_shap_p        = pd.DataFrame(shap_abs_p, columns=feature_cols)
df_shap_p['dong'] = parks_gdf['dong'].values

# 5) 행정동별 평균 SHAP 기여도 집계
dong_shap_mean = df_shap_p.groupby('dong').mean()

# 6) 행정동별 Top3 피처 추출
top3 = dong_shap_mean.apply(lambda row: row.nlargest(3).index.tolist(), axis=1)
df_top3 = (
    pd.DataFrame(top3.tolist(), index=top3.index, columns=['Top1','Top2','Top3'])
      .reset_index()
      .rename(columns={'index':'dong'})
)

# 7) 결과 확인
print(df_top3.head())
# Out:
#    dong                    Top1                  Top2                  Top3
# 0  가락본동                 end_cos                 fee1H               end_sin
# 1  가리봉동               cctv_r300  total_parking_spaces              bus_r300
# 2   가산동  Weekday_operatingHours               end_cos                 fee1H
# 3  가양1동               cctv_r300                 fee1H  total_parking_spaces
# 4  가양2동    total_parking_spaces              bus_r300             cctv_r300

# %%
# 1) 실제 complaints_level: parks_gdf 에 이미 있다면 바로 사용
#    없다면, 원본 complaints_df 등에서 행정동별로 집계해서 merge

# 예: 원본 parks_df 에 'complaints_level' 컬럼이 있다고 가정
actual = parks_gdf.groupby('dong')['complaint_level'] \
                   .agg(lambda x: x.mode()[0]) \
                   .reset_index()

# 2) 예측 complaints_level
predicted = pd.DataFrame({
    'dong': parks_gdf['dong'],
    'predicted_level': rf.predict(parks_gdf[feature_cols])
}).groupby('dong')['predicted_level'] \
  .agg(lambda x: x.mode()[0]) \
  .reset_index()

# 3) df_top3 에 결합
df_insight = (
    df_top3
      .merge(actual,    on='dong', how='left')
      .merge(predicted, on='dong', how='left')
)

df_insight.head()
# Out:
#    dong                    Top1                  Top2                  Top3  \
# 0  가락본동                 end_cos                 fee1H               end_sin
# 1  가리봉동               cctv_r300  total_parking_spaces              bus_r300
# 2   가산동  Weekday_operatingHours               end_cos                 fee1H
# 3  가양1동               cctv_r300                 fee1H  total_parking_spaces
# 4  가양2동    total_parking_spaces              bus_r300             cctv_r300
#
#   complaint_level  predicted_level
# 0               2                2
# 1               1                1
# 2               0                0
# 3               0                0
# 4               0                0

# %%
import pandas as pd

# 1. 두 CSV 파일 불러오기
df1 = pd.read_csv('src/RF_parksdf_week.csv')
df2 = pd.read_csv('src/RF_parksdf_weeks.csv')

# 2. 데이터프레임 전체 비교
if df1.equals(df2):
    print("✅ 두 CSV 파일은 완전히 동일합니다.")
else:
    print("❌ 두 CSV 파일은 다릅니다.")
# Out:
# ✅ 두 CSV 파일은 완전히 동일합니다.
